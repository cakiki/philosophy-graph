# %%
from IPython.core.display import HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# !pip install -q torch

# %%
import faiss
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
from transformers import AutoTokenizer, TFAutoModel
from elasticsearch import Elasticsearch, helpers
from elasticsearch_dsl import Search, Q, SF

# %%
es = Elasticsearch()
es.ping()
# Out:
# True

# %%
universal_sentence_encoder = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")
tokenizer = AutoTokenizer.from_pretrained('allenai/specter')
model = TFAutoModel.from_pretrained('allenai/specter', from_pt=True)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['embeddings.position_ids']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
specter = np.load('../data/spectre_embeddings.npy')
abstracts =  np.load('../data/use_abstract_embeddings.npy')
article_texts =  np.load('../data/use_article_embeddings.npy')
homophily_plato = np.load('../data/old_node2vec_embeddings/homophily_embeddings.npy')
plato = pd.read_pickle('../data/plato.pkl')
articles = pd.read_pickle('../data/to_index_p4.pkl')
articles.dropna(axis=0, inplace=True)
articles.reset_index(inplace=True)
articles
# Out:
#       index     id                         title  \
# 0         0     P0                     Abduction
# 1         1     P1            Affirmative Action
# 2         2     P2    Aesthetics of the Everyday
# 3         3     P3     Wittgenstein’s Aesthetics
# 4         4     P4     Schopenhauer’s Aesthetics
# ...     ...    ...                           ...
# 7216   6084  W6084           Stanisław Krajewski
# 7217   6085  W6085  Patrick Stokes (philosopher)
# 7218   6086  W6086                    Ernst Mach
# 7219   6087  W6087                Jessica Pierce
# 7220   6088  W6088            Hans-Georg Gadamer
#
#                                                abstract  \
# 0     In the philosophical literature, the term “abd...
# 1     “Affirmative action” means positive steps take...
# 2     In the history of Western aesthetics, the subj...
# 3     Given the extreme importance that Wittgenstein...
# 4     The focus of this entry is on Schopenhauer’s a...
# ...                                                 ...
# 7216  Stanisław Krajewski (born 1950) is a Polish ph...
# 7217  Patrick Stokes (born 1978) is an Australian ph...
# 7218  Ernst Waldfried Josef Wenzel Mach (; German: [...
# 7219  Jessica Pierce (born October 21, 1965) is an A...
# 7220  Hans-Georg Gadamer (; German: [ˈɡaːdamɐ]; Febr...
#
#                                                    text
# 0     \n1. Abduction: The General Idea\n\nYou happen...
# 1     \n1. In the Beginning\n\n\nIn 1972, affirmativ...
# 2     \n1. Recent History\n\nWith the establishment ...
# 3     \n1. The Critique of Traditional Aesthetics\n\...
# 4     \n1. Brief Background\n\n\nBy the 1870s, Arthu...
# ...                                                 ...
# 7216  Stanisław Krajewski (born 1950) is a Polish ph...
# 7217  Patrick Stokes (born 1978) is an Australian ph...
# 7218  Ernst Waldfried Josef Wenzel Mach (; German: [...
# 7219  Jessica Pierce (born October 21, 1965) is an A...
# 7220  Hans-Georg Gadamer (; German: [ˈɡaːdamɐ]; Febr...
#
# [7221 rows x 5 columns]

# %%
# %%time
lookup = {"P": "the Stanford Plato Encyclopedia", "W":"the Wikipedia Philosophers Collection"}
query = "language games"

s = Search(using=es, index="philosophy")

# s.query = Q("match", title=query)
s.query = Q("multi_match", query=query, fields=['title', 'abstract', 'article'])
s = s[:20]

response = s.execute()
for hit in response:
    print(f"{hit.title} - ID: {hit.meta.id} from {lookup[hit.meta.id[0]]} SCORE: {hit.meta.score}")
    print("*************************************************************************************************************************")
# Out:
# Logic and Games - ID: P973 from the Stanford Plato Encyclopedia SCORE: 10.573457
# *************************************************************************************************************************
# Logics for Analyzing Games - ID: P974 from the Stanford Plato Encyclopedia SCORE: 9.614387
# *************************************************************************************************************************
# Logics for Analyzing Power in Normal Form Games - ID: P674 from the Stanford Plato Encyclopedia SCORE: 9.523955
# *************************************************************************************************************************
# Jason Silva - ID: W1401 from the Wikipedia Philosophers Collection SCORE: 8.676296
# *************************************************************************************************************************
# Byram D. Avari - ID: W3379 from the Wikipedia Philosophers Collection SCORE: 8.661753
# *************************************************************************************************************************
# Horus (athlete) - ID: W1757 from the Wikipedia Philosophers Collection SCORE: 8.300993
# *************************************************************************************************************************
# Games, Full Abstraction and Full Completeness - ID: P975 from the Stanford Plato Encyclopedia SCORE: 8.163866
# *************************************************************************************************************************
# Evolutionary Game Theory - ID: P1077 from the Stanford Plato Encyclopedia SCORE: 7.7155094
# *************************************************************************************************************************
# Peter Ludlow - ID: W5740 from the Wikipedia Philosophers Collection SCORE: 7.7051945
# *************************************************************************************************************************
# Epistemic Foundations of Game Theory - ID: P972 from the Stanford Plato Encyclopedia SCORE: 7.5702834
# *************************************************************************************************************************
# Alexander R. Galloway - ID: W666 from the Wikipedia Philosophers Collection SCORE: 7.309137
# *************************************************************************************************************************
# Religious Language - ID: P257 from the Stanford Plato Encyclopedia SCORE: 7.0318823
# *************************************************************************************************************************
# Private Language - ID: P348 from the Stanford Plato Encyclopedia SCORE: 7.0318823
# *************************************************************************************************************************
# Distributive Justice and Empirical Moral Psychology - ID: P1196 from the Stanford Plato Encyclopedia SCORE: 6.7350154
# *************************************************************************************************************************
# Stefano Gualeni - ID: W5494 from the Wikipedia Philosophers Collection SCORE: 6.604768
# *************************************************************************************************************************
# Peregrinus Proteus - ID: W153 from the Wikipedia Philosophers Collection SCORE: 6.427786
# *************************************************************************************************************************
# Dialogical Logic - ID: P676 from the Stanford Plato Encyclopedia SCORE: 6.427786
# *************************************************************************************************************************
# Dependence Logic - ID: P678 from the Stanford Plato Encyclopedia SCORE: 6.402942
# *************************************************************************************************************************
# James P. Carse - ID: W5250 from the Wikipedia Philosophers Collection SCORE: 6.2600417
# *************************************************************************************************************************
# Kelly Oliver - ID: W4060 from the Wikipedia Philosophers Collection SCORE: 6.2600417
# *************************************************************************************************************************
# CPU times: user 12.9 ms, sys: 14.9 ms, total: 27.8 ms
# Wall time: 225 ms

# %%
specter_index = faiss.IndexFlatIP(specter.shape[-1])
abstracts_index = faiss.IndexFlatIP(abstracts.shape[-1])
article_texts_index = faiss.IndexFlatIP(article_texts.shape[-1])
plato_index = faiss.IndexFlatIP(homophily_plato.shape[-1])

# %%
# %%time
specter_index.add(specter)
abstracts_index.add(abstracts)
article_texts_index.add(article_texts)
plato_index.add(homophily_plato)
# Out:
# CPU times: user 12 ms, sys: 16.3 ms, total: 28.2 ms
# Wall time: 26.3 ms

# %%
# %%time
query = """If a person's head moves, she may or may not have moved her head, and, if she did move it, 
        she may have actively performed the movement of her head or merely, by doing something else, 
        caused a passive movement."""
query_use_embedding = universal_sentence_encoder([query]).numpy()
inputs = tokenizer("Sociology " + query, padding=True, truncation=True, return_tensors="tf", max_length=512)
specter_embedding = model(**inputs).last_hidden_state[:, 0, :].numpy()
# Out:
# CPU times: user 969 ms, sys: 111 ms, total: 1.08 s
# Wall time: 209 ms

# %% [markdown]
# ### USE Abstract:

# %%
# %%time
d, i = abstracts_index.search(query_use_embedding, 10)
articles.iloc[i.squeeze()]
# Out:
# CPU times: user 234 ms, sys: 0 ns, total: 234 ms
# Wall time: 10.1 ms
#       index     id                                              title  \
# 1694   1694  P1694                                             Action
# 988     988   P988  Incompatibilist (Nondeterministic) Theories of...
# 1691   1691  P1691                Action-based Theories of Perception
# 1328   1328  P1328             Higher-Order Theories of Consciousness
# 1337   1337  P1337                             Temporal Consciousness
# 1136   1136  P1136                                   Epiphenomenalism
# 479     479   P479          Newton’s Views on Space, Time, and Motion
# 869     869   P869                                 Identity Over Time
# 1545   1545  P1545                                  Personal Autonomy
# 515     515   P515   The Epistemic Condition for Moral Responsibility
#
#                                                abstract  \
# 1694  If a person's head moves, she may or may not h...
# 988   To have free will is to have what it takes to ...
# 1691  Action is a means of acquiring perceptual info...
# 1328  Higher-order theories of consciousness try to ...
# 1337  In ordinary conscious experience, consciousnes...
# 1136  Epiphenomenalism is the view that mental event...
# 479   Isaac Newton founded classical mechanics on th...
# 869   Irving Copi once defined the problem of identi...
# 1545  Autonomous agents are self-governing agents. B...
# 515   Philosophers usually acknowledge two individua...
#
#                                                    text
# 1694  \n1. The Nature of Action and Agency\n\n\nIt h...
# 988   \n1. Noncausal Theories\n\nSome incompatibilis...
# 1691  \n1. Early Action-Based Theories\nTwo doctrine...
# 1328  \n1. Kinds of Consciousness\n\nOne of the adva...
# 1337  \n1. Three Models of Temporal Consciousness\n1...
# 1136  \n1. Traditional Arguments (A) Pro\n\nMany phi...
# 479   \n1. Overview of the Scholium\n\n Today, Newto...
# 869   \n1. Introduction\n\nAs a number of philosophe...
# 1545  \n1. Introduction\n\n\nWhen people living in s...
# 515   \n1. The Epistemic Condition\n1.1 Contents of ...

# %% [markdown]
# ### USE Text

# %%
# %%time
d, i = article_texts_index.search(query_use_embedding, 10)
articles.iloc[i.squeeze()]
# Out:
# CPU times: user 673 ms, sys: 0 ns, total: 673 ms
# Wall time: 28.1 ms
#       index     id                                      title  \
# 1578   1578  P1578             Aristotle’s Natural Philosophy
# 748     748   P748                          Louis de La Forge
# 1355   1355  P1355                              Compatibilism
# 1238   1238  P1238                         Descartes’ Physics
# 479     479   P479  Newton’s Views on Space, Time, and Motion
# 1545   1545  P1545                          Personal Autonomy
# 1465   1465  P1465           Japanese Zen Buddhist Philosophy
# 720     720   P720                           Antoine Le Grand
# 1691   1691  P1691        Action-based Theories of Perception
# 838     838   P838            Space and Time: Inertial Frames
#
#                                                abstract  \
# 1578  Aristotle had a lifelong interest in the study...
# 748   Louis de la Forge was among the first group of...
# 1355  Compatibilism offers a solution to the free wi...
# 1238  While René Descartes (1596–1650) is well-known...
# 479   Isaac Newton founded classical mechanics on th...
# 1545  Autonomous agents are self-governing agents. B...
# 1465  Zen aims at the perfection of personhood. To t...
# 720   Antoine Le Grand (1629–1699) was a philosopher...
# 1691  Action is a means of acquiring perceptual info...
# 838   A “frame of reference” is a standard relative ...
#
#                                                    text
# 1578  \n1. Natures\n\n Nature, according to Aristotl...
# 748   \n1. Life and Works\n\nLa Forge was born on 24...
# 1355  \n1. Free Will and the Problem of Causal Deter...
# 1238  \n1. A Brief History of Descartes’ Scientific ...
# 479   \n1. Overview of the Scholium\n\n Today, Newto...
# 1545  \n1. Introduction\n\n\nWhen people living in s...
# 1465  \n1. The Meaning of the Term Zen\n\nThe design...
# 720   \n1. Life and Writings\n\n\nLe Grand lived in ...
# 1691  \n1. Early Action-Based Theories\nTwo doctrine...
# 838   \n1. Relativity and reference frames in classi...

# %% [markdown]
# ### Specter embeddings

# %%
# %%time
d, i = specter_index.search(specter_embedding, 10)
articles.iloc[i.squeeze()]
# Out:
# CPU times: user 801 ms, sys: 0 ns, total: 801 ms
# Wall time: 31.9 ms
#       index     id                                      title  \
# 1694   1694  P1694                                     Action
# 6013   4760  W4760                           Peter G. Ossorio
# 1524   1524  P1524                                Behaviorism
# 10       10    P10                                     Agency
# 1691   1691  P1691        Action-based Theories of Perception
# 1430   1430  P1430                   Margaret Lucas Cavendish
# 479     479   P479  Newton’s Views on Space, Time, and Motion
# 1146   1146  P1146      The Psychology of Normative Cognition
# 1695   1695  P1695                              Shared Agency
# 6986   5832  W5832                          Rebecca Goldstein
#
#                                                abstract  \
# 1694  If a person's head moves, she may or may not h...
# 6013  Peter G. Ossorio (4 May 1926 – 24 April 2007) ...
# 1524  It has sometimes been said that “behave is wha...
# 10    In very general terms, an agent is a being wit...
# 1691  Action is a means of acquiring perceptual info...
# 1430  Margaret Lucas Cavendish was a philosopher, po...
# 479   Isaac Newton founded classical mechanics on th...
# 1146  From an early age, humans exhibit a tendency t...
# 1695  Sometimes individuals act together, and someti...
# 6986  Rebecca Newberger Goldstein (born February 23,...
#
#                                                    text
# 1694  \n1. The Nature of Action and Agency\n\n\nIt h...
# 6013  Peter G. Ossorio (4 May 1926 – 24 April 2007) ...
# 1524  \n1. What is Behaviorism?\n\n\nOne has to be c...
# 10    \n1. Introduction\nIn a very broad sense, agen...
# 1691  \n1. Early Action-Based Theories\nTwo doctrine...
# 1430  \n1. Introduction and Biography\n\nMargaret Lu...
# 479   \n1. Overview of the Scholium\n\n Today, Newto...
# 1146  \n1. A Psychological Capacity Dedicated to Nor...
# 1695  \n1. The traditional ontological problem and t...
# 6986  Rebecca Newberger Goldstein (born February 23,...

# %% [markdown]
# ### Graph embeddings

# %%
starting_node = 1694

# %%
# %%time
d, i = plato_index.search(homophily_plato[starting_node:starting_node+1], 10)
plato.iloc[i.squeeze()][['title', 'related_entries']]
# Out:
# CPU times: user 688 ms, sys: 0 ns, total: 688 ms
# Wall time: 29.7 ms
#                                                   title  \
# 1694                                             Action
# 1689                Actualism and Possibilism in Ethics
# 10                                               Agency
# 365       Practical Reason and the Structure of Actions
# 1662                                   Weakness of Will
# 1695                                      Shared Agency
# 820                                           Intention
# 1703                                          Abilities
# 1621               Gertrude Elizabeth Margaret Anscombe
# 514   Moral Responsibility and the Principle of Alte...
#
#                                         related_entries
# 1694  [agency, shared-agency, davidson, intention, p...
# 1689  [action, dynamic-choice, consequentialism, con...
# 10    [action, shared-agency, anscombe, personal-aut...
# 365                [agency, davidson, practical-reason]
# 1662  [action, aristotle-ethics, davidson, practical...
# 1695  [action, agency, collective-intentionality, pr...
# 820   [action, agency, shared-agency, dynamic-choice...
# 1703  [action, compatibilism, conditionals, disposit...
# 1621  [action, consequentialism, davidson, double-ef...
# 514   [abilities, action, blame, compatibilism, dete...
