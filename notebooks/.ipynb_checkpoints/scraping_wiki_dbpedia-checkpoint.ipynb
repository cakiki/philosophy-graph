# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
# !pip install pymediawiki

# %%
from bs4 import BeautifulSoup
from urllib import request
from itertools import chain
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import numpy as np
import networkx as nx
from mediawiki import MediaWiki

# %%
def philosopher_influenced(philosopher_url, endpoint="http://localhost:8890/sparql"):
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery("""
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        SELECT ?influenced
        WHERE {{ <http://dbpedia.org/resource/{x}> dbo:influenced ?influenced }}
    """.format(x=philosopher_url))
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    direct_results = [result['influenced']['value'] for result in results['results']['bindings']]

    sparql.setQuery("""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    SELECT ?influenced
    WHERE {{ <http://dbpedia.org/resource/{x}> ^dbo:influencedBy ?influenced }}
    """.format(x=philosopher_url))
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    indirect_results = [result['influenced']['value'] for result in results['results']['bindings']]
    results = list(set(direct_results+indirect_results))
    return [result.split('/')[-1] for result in results]

def philosopher_influenced_by(philosopher_url, endpoint="http://localhost:8890/sparql"):
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery("""
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        SELECT ?influencedBy
        WHERE {{ <http://dbpedia.org/resource/{x}> dbo:influencedBy ?influencedBy }}
    """.format(x=philosopher_url))
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    direct_results = [result['influencedBy']['value'] for result in results['results']['bindings']]

    sparql.setQuery("""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    SELECT ?influencedBy
    WHERE {{ <http://dbpedia.org/resource/{x}> ^dbo:influenced ?influencedBy }}
    """.format(x=philosopher_url))
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    indirect_results = [result['influencedBy']['value'] for result in results['results']['bindings']]
    results = list(set(direct_results+indirect_results))
    return [result.split('/')[-1] for result in results]

def get_name(philosopher_url, endpoint="http://localhost:8890/sparql"):
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery("""
                    PREFIX dbo: <http://dbpedia.org/ontology/>
                    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
                    SELECT ?name
                    WHERE {{ <http://dbpedia.org/resource/{x}> dbp:name ?name}}
                    """.format(x=philosopher_url))
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    return [result['name']['value'] for result in results['results']['bindings']]

def get_title(url, endpoint="http://localhost:8890/sparql"):
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery("""
                    PREFIX dbo: <http://dbpedia.org/ontology/>
                    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
                    SELECT ?title
                    WHERE {{ <http://dbpedia.org/resource/{x}> dbp:title ?title}}
                    """.format(x=url))
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    return [result['title']['value'] for result in results['results']['bindings']]

def get_notable_ideas(philosopher_url, endpoint="http://localhost:8890/sparql"):
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery("""
                    PREFIX dbo: <http://dbpedia.org/ontology/>
                    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
                    SELECT ?idea
                    WHERE {{ <http://dbpedia.org/resource/{x}> dbo:notableIdea ?idea}}
                    """.format(x=philosopher_url))
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    ideas =  [result['idea']['value'] for result in results['results']['bindings']]
    return [idea.split('/')[-1] for idea in ideas]

def get_abstract(url, endpoint="http://localhost:8890/sparql"):
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery("""
                    PREFIX dbo: <http://dbpedia.org/ontology/>
                    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
                    SELECT ?abstract
                    WHERE {{ <http://dbpedia.org/resource/{x}> dbo:abstract ?abstract}}
                    """.format(x=url))
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return results['results']['bindings']

def return_en_result(abstract_list):
    try:
        to_return = [result['abstract']['value'] for result in abstract_list if result['abstract']['xml:lang']=='en'][0]
    except:
        to_return = []
    return to_return

def get_dbpedia_philosophers(endpoint="http://localhost:8890/sparql"):
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery("""
                    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
                    SELECT ?person
                    WHERE { ?person a dbo:Philosopher}
                    """)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    dbpedia_philosophers = [result['person']['value'].split('/')[-1] for result in results['results']['bindings']]
    return dbpedia_philosophers

def get_wikipedia_philosophers(list_url, n_letters):
    response = request.urlopen(list_url)
    html = response.read()
    soup  = BeautifulSoup(html, 'html.parser')
    philosopher_urls = [thing.select('a[href*="wiki/"]') for thing in soup.find_all('ul')[1:n_letters]]
    philosopher_urls = chain(*philosopher_urls)
    philosopher_urls = [thing['href'] for thing in philosopher_urls]
    return philosopher_urls
def get_wiki_article(url):
    try:
        return wikipedia.page(url).content
    except:
        return -1

# %%
# %%time
philosophers_a_c = 'https://en.wikipedia.org/wiki/List_of_philosophers_(A%E2%80%93C)'
philosophers_d_h = 'https://en.wikipedia.org/wiki/List_of_philosophers_(D%E2%80%93H)'
philosophers_i_q = 'https://en.wikipedia.org/wiki/List_of_philosophers_(I%E2%80%93Q)'
philosophers_r_z = 'https://en.wikipedia.org/wiki/List_of_philosophers_(R%E2%80%93Z)'

list_url = [philosophers_a_c, philosophers_d_h, philosophers_i_q, philosophers_r_z]
n_letters = [4, 6, 10, 10]

wikipedia_urls = [get_wikipedia_philosophers(list_url=a, n_letters=b) for a,b in zip(list_url, n_letters)]
wikipedia_urls = [url.split('/wiki/')[-1] for url in chain(*wikipedia_urls)]
dbpedia_urls = get_dbpedia_philosophers()
# Out:
# CPU times: user 999 ms, sys: 13.3 ms, total: 1.01 s
# Wall time: 1.83 s

# %%
len(wikipedia_urls)
# Out:
# 1734

# %%
len(dbpedia_urls)
# Out:
# 5123

# %%
philosopher_urls = list(set(wikipedia_urls) | set(dbpedia_urls))
len(philosopher_urls)
# Out:
# 6089

# %%
dataset = pd.DataFrame(pd.Series(philosopher_urls), columns=['philosopher_url'])
dataset
# Out:
#                    philosopher_url
# 0                      Stephen_Law
# 1              Henry_S._Richardson
# 2               John_Amos_Comenius
# 3                      Javier_Gomá
# 4                       Oskar_Negt
# ...                            ...
# 6084           Stanisław_Krajewski
# 6085  Patrick_Stokes_(philosopher)
# 6086                    Ernst_Mach
# 6087                Jessica_Pierce
# 6088            Hans-Georg_Gadamer
#
# [6089 rows x 1 columns]

# %%
# %%time
dataset['name'] = dataset['philosopher_url'].apply(get_name)
dataset['abstract'] = dataset['philosopher_url'].apply(get_abstract)
dataset['abstract'] = dataset['abstract'].apply(return_en_result)
dataset['notable_ideas'] = dataset['philosopher_url'].apply(get_notable_ideas)
dataset['influence_inbound'] = dataset['philosopher_url'].apply(philosopher_influenced_by) # Influenced me
dataset['influence_outbound'] = dataset['philosopher_url'].apply(philosopher_influenced) # I influenced
dataset['undirected_influence'] = dataset.apply(lambda x: list(set(x['influence_inbound']+x['influence_outbound'])),axis=1)
dataset = dataset.applymap(lambda x: np.nan if len(x)==0 else x)
dataset
# Out:
# CPU times: user 1min 11s, sys: 11.8 s, total: 1min 23s
# Wall time: 3min 18s
#                    philosopher_url  \
# 0                      Stephen_Law
# 1              Henry_S._Richardson
# 2               John_Amos_Comenius
# 3                      Javier_Gomá
# 4                       Oskar_Negt
# ...                            ...
# 6084           Stanisław_Krajewski
# 6085  Patrick_Stokes_(philosopher)
# 6086                    Ernst_Mach
# 6087                Jessica_Pierce
# 6088            Hans-Georg_Gadamer
#
#                                             name  \
# 0                                  [Stephen Law]
# 1                          [Henry S. Richardson]
# 2     [John Amos Comenius, Johann Amos Comenius]
# 3                           [Javier Gomá Lanzón]
# 4                                            NaN
# ...                                          ...
# 6084                                         NaN
# 6085                            [Patrick Stokes]
# 6086                                [Ernst Mach]
# 6087                            [Jessica Pierce]
# 6088                        [Hans-Georg Gadamer]
#
#                                                abstract  \
# 0     Stephen Law  (born 1960) is an English philoso...
# 1     Henry S. Richardson is an American philosopher...
# 2     John Amos Comenius (Czech: Jan Amos Komenský; ...
# 3     Javier Gomá Lanzón (Bilbao, 24 May 1965) is a ...
# 4     Oskar Negt (German pronunciation: [ˈneːkt]; bo...
# ...                                                 ...
# 6084  Stanisław Krajewski (born 1950) is a Polish ph...
# 6085  Patrick Stokes (born 1978) is an Australian ph...
# 6086  Ernst Waldfried Josef Wenzel Mach (; German: [...
# 6087  Jessica Pierce (born October 21, 1965) is an A...
# 6088  Hans-Georg Gadamer (; German: [ˈɡaːdamɐ]; Febr...
#
#                                           notable_ideas  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6084                                                NaN
# 6085                                                NaN
# 6086                                                NaN
# 6087                                                NaN
# 6088  [Consciousness, Fusion_of_horizons, Practical_...
#
#                                       influence_inbound  \
# 0                                                   NaN
# 1                                          [John_Rawls]
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6084                                                NaN
# 6085                                                NaN
# 6086  [Gustav_Fechner, George_Berkeley, Andreas_von_...
# 6087                                                NaN
# 6088  [Wilhelm_Dilthey, Friedrich_Schleiermacher, Ka...
#
#                                      influence_outbound  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6084                                                NaN
# 6085                                                NaN
# 6086  [Pierre_Duhem, Henri_Poincaré, Ludwig_Boltzman...
# 6087                                                NaN
# 6088  [Babette_Babich, John_McDowell, Reinhart_Kosel...
#
#                                    undirected_influence
# 0                                                   NaN
# 1                                          [John_Rawls]
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6084                                                NaN
# 6085                                                NaN
# 6086  [William_James, Friedrich_Hayek, Albert_Einste...
# 6087                                                NaN
# 6088  [Augustine, Paul_Natorp, Martin_Heidegger, Nic...
#
# [6089 rows x 7 columns]

# %%
# Out:
#                    philosopher_url  \
# 0                      Stephen_Law
# 1              Henry_S._Richardson
# 2               John_Amos_Comenius
# 3                      Javier_Gomá
# 4                       Oskar_Negt
# ...                            ...
# 6084           Stanisław_Krajewski
# 6085  Patrick_Stokes_(philosopher)
# 6086                    Ernst_Mach
# 6087                Jessica_Pierce
# 6088            Hans-Georg_Gadamer
#
#                                             name  \
# 0                                  [Stephen Law]
# 1                          [Henry S. Richardson]
# 2     [John Amos Comenius, Johann Amos Comenius]
# 3                           [Javier Gomá Lanzón]
# 4                                            NaN
# ...                                          ...
# 6084                                         NaN
# 6085                            [Patrick Stokes]
# 6086                                [Ernst Mach]
# 6087                            [Jessica Pierce]
# 6088                        [Hans-Georg Gadamer]
#
#                                                abstract  \
# 0     Stephen Law  (born 1960) is an English philoso...
# 1     Henry S. Richardson is an American philosopher...
# 2     John Amos Comenius (Czech: Jan Amos Komenský; ...
# 3     Javier Gomá Lanzón (Bilbao, 24 May 1965) is a ...
# 4     Oskar Negt (German pronunciation: [ˈneːkt]; bo...
# ...                                                 ...
# 6084  Stanisław Krajewski (born 1950) is a Polish ph...
# 6085  Patrick Stokes (born 1978) is an Australian ph...
# 6086  Ernst Waldfried Josef Wenzel Mach (; German: [...
# 6087  Jessica Pierce (born October 21, 1965) is an A...
# 6088  Hans-Georg Gadamer (; German: [ˈɡaːdamɐ]; Febr...
#
#                                           notable_ideas  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6084                                                NaN
# 6085                                                NaN
# 6086                                                NaN
# 6087                                                NaN
# 6088  [Consciousness, Fusion_of_horizons, Practical_...
#
#                                       influence_inbound  \
# 0                                                   NaN
# 1                                          [John_Rawls]
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6084                                                NaN
# 6085                                                NaN
# 6086  [Gustav_Fechner, George_Berkeley, Andreas_von_...
# 6087                                                NaN
# 6088  [Wilhelm_Dilthey, Friedrich_Schleiermacher, Ka...
#
#                                      influence_outbound
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6084                                                NaN
# 6085                                                NaN
# 6086  [Pierre_Duhem, Henri_Poincaré, Ludwig_Boltzman...
# 6087                                                NaN
# 6088  [Babette_Babich, John_McDowell, Reinhart_Kosel...
#
# [6089 rows x 6 columns]

# %%
dataset.to_csv('../data/wiki_dbpedia_philosophers.csv')

# %%
g = nx.DiGraph()

# %%
dataset[['philosopher_url', 'influence_outbound']].dropna().set_index('philosopher_url').to_dict()
# Out:
# {'influence_outbound': {'Gillian_Rose': ['Rowan_Williams',
#    'Geoffrey_Hill',
#    'Paul_Gilroy',
#    'John_Milbank',
#    'Slavoj_Žižek'],
#   'Alexander_Zinoviev': ['Jon_Elster',
#    'Boris_Grushin',
#    'Yuri_Levada',
#    'Georgy_Shchedrovitsky'],
#   'Sextus_of_Chaeronea': ['Apuleius',
#    'Herodes_Atticus',
#    'Marcus_Aurelius',
#    'Himerius'],
#   'Alexander_Potebnja': ['Lev_Vygotsky'],
#   'Antonio_Labriola': ['Benedetto_Croce',
#    'Georges_Sorel',
#    'Amadeo_Bordiga',
#    'Leon_Trotsky',
#    'Antonio_Gramsci'],
#   'Manuel_DeLanda': ['Levi_Bryant'],
#   'René_Guénon': ['Aleksandr_Dugin',
#    'Carl_Schmitt',
#    'Francis_Parker_Yockey',
#    'Jean_Hani',
#    'Philip_Sherrard',
#    'Michel_Valsan',
#    'Ali_Lakhani',
#    'Seyyed_Hossein_Nasr',
#    'Arturo_Reghini',
#    'Frithjof_Schuon',
#    'Ramon_Mujica_Pinilla',
#    'Harry_Oldmeadow',
#    'Seraphim_Rose',
#    'Wolfgang_Smith',
#    'Hamza_Yusuf',
#    'Gary_Snyder',
#    'Bernard_Philip_Kelly',
#    'Whitall_Perry',
#    'Hossein_Nasr',
#    'Valentin_Tomberg',
#    'Jean_Borella',
#    'Jacob_Needleman',
#    'Julius_Evola',
#    'Joseph_Epes_Brown',
#    'Mikky_Lafey',
#    'Boris_Mouravieff',
#    'Huston_Smith',
#    'Wendell_Berry',
#    'Éric_Geoffroy',
#    'Dominique_Venner',
#    'Algis_Uzdavinys',
#    'Dragoš_Kalajić',
#    'James_Cutsinger',
#    'Hans_Thomas_Hakl',
#    'Richard_Smoley',
#    'Alain_de_Benoist',
#    'Ananda_Coomaraswamy'],
#   'Ludwig_Klages': ['Emil_Cioran', 'Walter_Benjamin'],
#   'David_Lewis_(philosopher)': ['Peter_Railton',
#    'Barry_Loewer',
#    'Gideon_Rosen',
#    'Bob_Brandom',
#    'Mark_Johnston_(philosopher)',
#    'L.A._Paul',
#    'Ted_Sider',
#    'Theodore_Sider',
#    'Stathis_Psillos',
#    'John_Hawthorne',
#    'David_Velleman',
#    'Dean_Zimmerman'],
#   'Herman_Dooyeweerd': ['Hendrik_Hart', 'Cornelius_Van_Til'],
#   'Georges_Canguilhem': ['Pierre_Bourdieu',
#    'François_Dagognet',
#    'Jacques-Alain_Miller',
#    'Louis_Althusser',
#    'Michel_Foucault',
#    'Dominique_Lecourt',
#    'Gilbert_Simondon',
#    'Élisabeth_Roudinesco',
#    'Arnold_Davidson',
#    'Gilles_Deleuze'],
#   'Ullin_Place': ['David_Malet_Armstrong'],
#   'Sigmund_Freud': ['Erich_Fromm',
#    'Ray_Brassier',
#    'Avital_Ronell',
#    'Carl_Jung',
#    'Ágnes_Heller',
#    'Norbert_Elias',
#    'Bernard_Stiegler',
#    'David_Harvey',
#    'List_of_psychoanalytical_theorists',
#    'Peter_Wessel_Zapffe',
#    'Nancy_Chodorow',
#    'Augusto_Ponzio',
#    'Eugen_Bleuler',
#    'Erika_Fromm',
#    'Éric_Pichet',
#    'Luiz_Felipe_Pondé',
#    'Sándor_Ferenczi',
#    'David_Shakow',
#    'Renzo_Novatore',
#    'Erich_Neumann_(psychologist)',
#    'Karl_Koller_(ophthalmologist)',
#    'Herbert_Marcuse',
#    'Peter_Kropotkin',
#    'Otto_Rank',
#    'Hamid_Dabashi',
#    'Grete_L._Bibring',
#    'Robert_Anton_Wilson',
#    'Félix_Guattari',
#    'Slavoj_Žižek',
#    'Simone_Weil',
#    'Byung-Chul_Han',
#    'Renata_Salecl',
#    'Erving_Goffman',
#    'Luce_Irigaray',
#    'Hélène_Cixous',
#    'Otto_Gross',
#    'Mark_Fisher',
#    'Jacques_Lacan',
#    'Snell_Putney',
#    'Ferdinand_Ulrich',
#    'Mikhail_Bakhtin',
#    'List_of_psychoanalysts',
#    'Dimitrije_Mitrinović',
#    'Richard_J._Bernstein',
#    'Vladimir_Solovyov_(philosopher)',
#    'Judith_Butler',
#    'Sarah_Kofman',
#    'Michel_Onfray',
#    'Francis_Fukuyama',
#    'Bertram_Cohler',
#    'Kostas_Axelos',
#    'Benjamin_Drake_Wright',
#    'Hilary_Putnam',
#    'Domenico_Losurdo',
#    'John_Zerzan',
#    'Jürgen_Habermas',
#    'Laurence_A._Rickels',
#    'Simone_de_Beauvoir',
#    'Alenka_Zupančič',
#    'Eric_Berne',
#    'Walter_Kaufmann_(philosopher)',
#    'Helene_Deutsch',
#    'Sabina_Spielrein',
#    'Wendy_Brown_(political_theorist)',
#    'Georges_Sorel',
#    'Peter_Rollins',
#    'Steven_Marcus',
#    'Stephen_Hicks',
#    'Max_Horkheimer',
#    'Javier_Mariátegui',
#    'Cornelius_Castoriadis',
#    'Mladen_Dolar',
#    'Stanley_Cavell',
#    'Géza_Róheim',
#    'Gilles_Deleuze',
#    'Jacques_Derrida',
#    'Isaiah_Berlin',
#    'Alphonso_Lingis',
#    'Theodor_W._Adorno',
#    'Melanie_Klein',
#    'Bracha_L._Ettinger',
#    'Werner_Sombart',
#    'Norman_O._Brown',
#    'Bob_Black',
#    'Martin_Buber'],
#   'Jacques_Lacan': ['Kiarina_Kordela',
#    'Dominik_Finkelde',
#    'Judith_Butler',
#    'Renaud_Barbaras',
#    'Félix_Guattari',
#    'Slavoj_Žižek',
#    'Ian_Parker_(psychologist)',
#    'Alain_Badiou',
#    'Elisabeth_Roudinesco',
#    'Lacanian_movement',
#    'Elizabeth_Grosz',
#    'Mario_Christian_Meyer',
#    'Renata_Salecl',
#    'Simon_Critchley',
#    'Mladen_Dolar',
#    'Luce_Irigaray',
#    'Gilles_Deleuze',
#    'Mark_Fisher',
#    'Levi_Bryant',
#    'Jacques_Rancière',
#    'Jean_Laplanche',
#    'Boris_Groys',
#    'Jacques-Alain_Miller',
#    'Alenka_Zupančič',
#    'François_Laruelle',
#    'Bracha_L._Ettinger',
#    'Chantal_Mouffe',
#    'Duane_Rousselle',
#    'Adrian_Johnston_(philosopher)',
#    'Louis_Althusser',
#    'Éric_Laurent_(psychoanalyst)',
#    'Mari_Ruti',
#    'Julia_Kristeva',
#    'Ljubljana_school_of_psychoanalysis',
#    'Élisabeth_Roudinesco',
#    'François_Recanati',
#    'Peter_Rollins'],
#   'Émile_Chartier': ['Alain_de_Botton',
#    'Jean_Mistler',
#    'Simone_Weil',
#    'André_Maurois',
#    'Georges_Canguilhem',
#    'Raymond_Aron'],
#   'Antonio_Negri': ['Michael_Hardt'],
#   'Gregory_of_Nyssa': ['Pseudo-Dionysius_the_Areopagite'],
#   'Sotion_(Pythagorean)': ['Seneca_the_Younger'],
#   'Ludwig_Andreas_Feuerbach': ['Edmund_Montgomery', 'Marx_W._Wartofsky'],
#   'Karl_Marx': ['Erich_Fromm',
#    'J._Moufawad-Paul',
#    'Karl_Kautsky',
#    'Paul_Virilio',
#    'Paul_A._Baran',
#    'Ágnes_Heller',
#    'Karel_Kosík',
#    'Stephen_Hymer',
#    'David_Harvey',
#    'Nancy_Fraser',
#    'Ramkrishna_Bhattacharya',
#    'Raya_Dunayevskaya',
#    'Ernst_Bloch',
#    'Alexander_Zinoviev',
#    'Augustyn_Wróblewski',
#    'Ljubodrag_Simonović',
#    'Luiz_Carlos_Bresser-Pereira',
#    'Stephen_A._Webb',
#    'Antonio_Escohotado',
#    'Paul_Sweezy',
#    'Eleanor_Leacock',
#    'Augusto_Ponzio',
#    'Tan_Malaka',
#    'David_Gordon_(economist)',
#    'Ugo_Pagano',
#    'Li_Minqi',
#    'Gustavo_Bueno',
#    'Heinrich_Blücher',
#    'Robert_Paul_Wolff',
#    'Stephen_Resnick',
#    'François_Laruelle',
#    'Martin_Hägglund',
#    'George_Kline',
#    'Eric_Wolf',
#    'Ernesto_Laclau',
#    'Oskar_R._Lange',
#    'Juan_Carlos_Portantiero',
#    'Renzo_Novatore',
#    'George_Ritzer',
#    'Pierre_Clastres',
#    'Alexandre_Kojève',
#    'Arif_Dirlik',
#    'Tom_Rockmore',
#    'Robert_Rowthorn',
#    'Reiner_Grundmann',
#    'Herbert_Marcuse',
#    'Guy_Debord',
#    'Peter_Kropotkin',
#    'István_Mészáros_(philosopher)',
#    'Zaki_al-Arsuzi',
#    'Alain_de_Benoist',
#    'Gillian_Rose',
#    'Hamid_Dabashi',
#    'Hyman_Minsky',
#    'Robin_Hahnel',
#    'Michael_Hardt',
#    'Costanzo_Preve',
#    'Gayatri_Chakravorty_Spivak',
#    'Peter_Hallward',
#    'Leszek_Kołakowski',
#    'Lucien_Goldmann',
#    'José_Carlos_Mariátegui',
#    'Claude_Lefort',
#    'Michael_Walzer',
#    'Ion_Dragoumis',
#    'Félix_Guattari',
#    'Max_Adler_(Marxist)',
#    'Hardy_Hanappi',
#    'Slavoj_Žižek',
#    'Bill_Mitchell_(economist)',
#    'Walter_Benjamin',
#    'Alain_Badiou',
#    'Simone_Weil',
#    'György_Lukács',
#    'Benny_Lévy',
#    'Richard_D._Wolff',
#    'Sidney_Hook',
#    'Roy_Bhaskar',
#    'Adam_Schaff',
#    'Frantz_Fanon',
#    'Jörg_Huffschmid',
#    'Antonio_Labriola',
#    'Jonathan_Nitzan',
#    'Juan_José_Sebreli',
#    'Maurice_Dobb',
#    'Edward_Abramowski',
#    'Mark_Fisher',
#    'Jacques_Lacan',
#    'Estanislao_Zuleta',
#    "John_O'Neill_(philosopher)",
#    'Snell_Putney',
#    'Allen_W._Wood',
#    'Ferdinand_Ulrich',
#    'Said_Gafurov',
#    'Mikhail_Bakhtin',
#    'Evald_Ilyenkov',
#    'Irena_Krzywicka',
#    'Kojin_Karatani',
#    'Antonio_Gramsci',
#    'Saul_Alves_Martins',
#    'Henryk_Grossman',
#    'Jack_Amariglio',
#    'Chantal_Mouffe',
#    'Arno_J._Mayer',
#    'Eqbal_Ahmad',
#    'Ivan_Sviták',
#    'Étienne_Balibar',
#    'Boris_Kagarlitsky',
#    'Victor_Alekseyevich_Vaziulin',
#    'Richard_J._Bernstein',
#    'Vladimir_Solovyov_(philosopher)',
#    'Lev_Vygotsky',
#    'William_Davies_(political_writer)',
#    'G._A._Cohen',
#    'Joseph_Dietzgen',
#    'György_Márkus',
#    'Timothy_Morton',
#    'Amartya_Sen',
#    'Mikhail_Bakunin',
#    'Judith_Butler',
#    'Shimshon_Bichler',
#    'Georges_Friedmann',
#    'Gáspár_Miklós_Tamás',
#    'Herbert_McCabe',
#    'Giovanni_Arrighi',
#    'Joan_Robinson',
#    'Michel_Onfray',
#    'Zygmunt_Bauman',
#    'Francis_Fukuyama',
#    'Terry_Eagleton',
#    'Georgi_Plekhanov',
#    'Kostas_Axelos',
#    'Amina_Mama',
#    'Hilary_Putnam',
#    'Domenico_Losurdo',
#    'John_Zerzan',
#    'Jürgen_Habermas',
#    'Thomas_Piketty',
#    'Karl_Mannheim',
#    'Simone_de_Beauvoir',
#    'Philip_Green_(author)',
#    'Ralf_Dahrendorf__yes__1',
#    'Edgar_Morin',
#    'Jean-Paul_Sartre',
#    "Guillermo_O'Donnell",
#    'Michał_Kalecki',
#    'Wendy_Brown_(political_theorist)',
#    'Svetozar_Marković',
#    'Georges_Sorel',
#    'Peter_Manley_Scott',
#    'Tony_Lawson',
#    'Sheldon_Wolin',
#    'Jean_Baudrillard',
#    'Kozo_Uno',
#    'Nobuo_Okishio',
#    'Raymond_Williams',
#    'Peter_Rollins',
#    'Antonie_Pannekoek',
#    'Stuart_Hall_(cultural_theorist)',
#    'Rick_Kuhn',
#    'Stephen_Hicks',
#    'McKenzie_Wark',
#    'Alberto_Toscano',
#    'Max_Horkheimer',
#    'Karl_Polanyi',
#    'Gianni_Vattimo',
#    'Daniel_Guérin',
#    'Fredric_Jameson',
#    'Y._Michal_Bodemann',
#    'Debiprasad_Chattopadhyaya',
#    'E._P._Thompson',
#    'Miguel_Robles-Durán',
#    'Ashley_Dawson',
#    'Stephen_Marglin',
#    'Cornelius_Castoriadis',
#    'Fred_Newman_(philosopher)',
#    'Michel_Aflaq__1',
#    'Alexander_Tarasov',
#    'Gilles_Deleuze',
#    'Levi_Bryant',
#    'Mahdi_Amel',
#    'Jacques_Rancière',
#    'Jacques_Derrida',
#    'Nicos_Poulantzas',
#    'Masoud_Ahmadzadeh',
#    'Isaiah_Berlin',
#    'Murray_Bookchin',
#    'Mike_Davis_(scholar)',
#    'Karl_Korsch',
#    'Christopher_Freeman',
#    'Jean_Hyppolite',
#    'Theodor_W._Adorno',
#    'Duncan_K._Foley',
#    'Thomas_Nail',
#    'Nick_Land',
#    'Albert_Camus',
#    'Costas_Lapavitsas',
#    'Werner_Sombart',
#    'Norman_O._Brown',
#    'Henri_Lefebvre',
#    'Ladislaus_Bortkiewicz',
#    'Rogelio_Julio_Frigerio',
#    'Susan_Buck-Morss',
#    'Alasdair_MacIntyre',
#    'Mário_Ferreira_dos_Santos',
#    'Steve_Keen',
#    'Edward_Said',
#    'Louis_Althusser',
#    'Bernard_Bernier',
#    'Alexander_R._Galloway',
#    'Bob_Black',
#    'José_Guilherme_Merquior',
#    'Mark_Skousen',
#    'James_Crotty_(economist)',
#    'Natalia_Magnat',
#    'Frederic_Sterling_Lee',
#    'Bolívar_Echeverría',
#    'Chris_Harman',
#    'Antonio_Negri',
#    'Samuel_Bowles_(economist)',
#    'Raymond_Geuss'],
#   'Michel_Aflaq__1': ['Bashar_al-Assad',
#    'Salah_al-Din_al-Bitar',
#    'Nureddin_al-Atassi',
#    'Izzat_Ibrahim_ad-Douri',
#    'Hafiz_al-Assad',
#    'Amin_al-Hafiz',
#    'Akram_al-Hawrani',
#    'Abdullah_Rimawi',
#    'Assem_Qanso',
#    'Salah_Jadid',
#    'Saddam_Hussein',
#    'Ahmad_Hassan_al-Bakr',
#    'Fuad_al-Rikabi',
#    'Gamal_Abdel_Nasser'],
#   'Ludwig_Feuerbach': ['Mikhail_Bakunin',
#    'Sigmund_Freud',
#    'Max_Stirner',
#    'Bruno_Bauer',
#    'Georgi_Plekhanov',
#    'Friedrich_Nietzsche',
#    'Karl_Rahner',
#    'Charles_Darwin',
#    'Joseph_Dietzgen',
#    'Karl_Marx',
#    'Friedrich_Engels',
#    'Tan_Malaka',
#    'Richard_Wagner',
#    'Martin_Buber',
#    'Nikolay_Chernyshevsky'],
#   'Fazlur_Rahman_Malik': ['Mohamed_Talbi',
#    'Abdullah_Saeed_(professor)',
#    'Amina_Wadud',
#    "Abdullahi_Ahmed_An-Na'im",
#    'Nurcholish_Madjid',
#    'Ebrahim_Moosa'],
#   'Carl_Schmitt': ['Aleksandr_Dugin',
#    'Francis_Parker_Yockey',
#    'Avital_Ronell',
#    'Reinhart_Koselleck',
#    'Slavoj_Žižek',
#    'Walter_Benjamin',
#    'Friedrich_Hayek',
#    'Copenhagen_School_(international_relations)',
#    'Jiang_Shigong',
#    'Giorgio_Agamben',
#    'Leo_Strauss',
#    'Hans_Morgenthau',
#    'Alberto_Buela',
#    'Juan_José_Sebreli',
#    'Jürgen_Habermas',
#    'Hannah_Arendt',
#    'Jacques_Derrida',
#    'Mark_Lilla',
#    'Jacob_Taubes',
#    'Chantal_Mouffe',
#    'Adriana_Cavarero',
#    'Guillaume_Faye',
#    'Jaime_Guzmán',
#    'Alexandre_Kojève',
#    'Ernst_Jünger',
#    'Alain_de_Benoist',
#    'Antonio_Negri'],
#   'Franciscus_van_den_Enden': ['Baruch_de_Spinoza', 'Baruch_Spinoza'],
#   'Immanuel_Kant': ['Alvin_Plantinga',
#    'Roman_Ingarden',
#    'Karl_Kautsky',
#    'Carl_Jung',
#    'Christine_Korsgaard',
#    'Robert_Brandom',
#    'Charles_Parsons_(philosopher)',
#    'Roberto_Torretti',
#    'Hans_Christian_Ørsted',
#    'W._D._Ross',
#    'Friedrich_Nietzsche',
#    'Anthony_Steinbock',
#    'Leo_Strauss',
#    'Leonard_Nelson',
#    'Rudolf_Steiner',
#    'Gottlob_Frege',
#    'Alberto_Buela',
#    'Rudolf_Carnap',
#    'Nelson_Goodman',
#    'Robert_Paul_Wolff',
#    'Émile_Durkheim',
#    'Leonardo_Polo',
#    'Ernst_Cassirer',
#    'Hans_Vaihinger',
#    'Samuel_Todes',
#    'Elisabeth_Schellekens',
#    'August_Ludwig_Hülsen',
#    'John_Hick',
#    'C._A._Campbell',
#    'Henri_Poincaré',
#    'Dieter_Henrich',
#    'Alexandre_Kojève',
#    'Tom_Rockmore',
#    'Martin_Heidegger',
#    'Henri_Bergson',
#    'Graham_Harman',
#    'Herbert_Marcuse',
#    'August_Wilhelm_Schlegel',
#    'Hans-Georg_Gadamer',
#    'Vojin_Rakić',
#    'P._F._Strawson',
#    'Leszek_Kołakowski',
#    'Gillian_Rose',
#    'Peter_Hallward',
#    'T._M._Scanlon',
#    'Dominik_Finkelde',
#    'Thomas_Pogge',
#    'Seyla_Benhabib',
#    'Frithjof_Bergmann',
#    'Edward_J._Hall',
#    'Gottlob_Ernst_Schulze',
#    'Western_philosophy',
#    'Friedrich_Wilhelm_Joseph_Schelling',
#    'Michael_Oakeshott',
#    'Kenneth_Waltz',
#    'Ernst_Platner',
#    'Charles_Renouvier',
#    'John_McDowell',
#    'Slavoj_Žižek',
#    'Thomas_Kuhn',
#    'L._E._J._Brouwer',
#    'Rudolf_Eisler',
#    'Karl_Leonhard_Reinhold',
#    'Søren_Kierkegaard',
#    'George_Wilhelm_Friedrich_Hegel',
#    'Sir_William_Hamilton,_9th_Baronet',
#    'Jesús_Padilla_Gálvez',
#    'J._L._Austin',
#    'Simone_Weil',
#    'Karl_Jaspers',
#    'Christian_Jakob_Kraus',
#    'György_Lukács',
#    'Kuno_Fischer',
#    'Wilfrid_Sellars',
#    'Eliseo_Vivas',
#    'Edmund_Husserl',
#    'Roy_Bhaskar',
#    'Friedrich_Adolf_Trendelenburg',
#    'Juan_José_Sebreli',
#    'Joseph_Maréchal',
#    'Raymond_Aron',
#    'Thomas_Wizenmann',
#    'T._H._Green',
#    'Gordon_Finlayson',
#    'Ernest_Renan',
#    'Jacques_Lacan',
#    'Bruno_Bauch',
#    'Heinrich_Rickert',
#    'Samuel_Alexander',
#    'Allen_W._Wood',
#    'Paul_Guyer',
#    'Kojin_Karatani',
#    'Michael_Friedman_(philosopher)',
#    'Mikhail_Bakhtin',
#    'Emil_Lask',
#    'Fernando_González_(writer)',
#    'Wolfgang_Cramer',
#    'Edward_S._Casey',
#    'Jean-Michel_Berthelot',
#    'Semyon_Frank',
#    'Seana_Shiffrin',
#    'Karl_Rahner',
#    'Jakob_Sigismund_Beck',
#    'Wilhelm_von_Humboldt',
#    'Hermann_Weyl',
#    'Kenneth_Binmore',
#    'Émile_Meyerson',
#    'Vladimir_Solovyov_(philosopher)',
#    'Richard_J._Bernstein',
#    'Jean-Luc_Marion',
#    'Léon_Brunschvicg',
#    'Joseph_Dietzgen',
#    'Donald_Davidson_(philosopher)',
#    'Thomas_E._Hill_(academic)',
#    'Simon_Critchley',
#    'Afrikan_Spir',
#    'David_Hilbert',
#    'Bernard_Gert',
#    'Carl_Schmitt',
#    'José_Ortega_y_Gasset',
#    'Karl-Otto_Apel',
#    'Emil_Cioran',
#    'Friedrich_Schlegel',
#    'Nikolai_Berdyaev',
#    'Luciano_Floridi',
#    'Friedrich_Eduard_Beneke',
#    'Arthur_Schopenhauer',
#    'Mario_Christian_Meyer',
#    'Jules_Vuillemin',
#    'Alejandro_Korn',
#    'Eduard_Zeller',
#    'Hilary_Putnam',
#    'Domenico_Losurdo',
#    'Johann_Friedrich_Herbart',
#    'Jürgen_Habermas',
#    'Alexander_Dobrokhotov',
#    'Kurt_Mueller-Vollmer',
#    'David_Carr_(phenomenology_scholar)',
#    'Boris_Groys',
#    'Simone_de_Beauvoir',
#    'Sally_Sedgwick',
#    'African_Spir',
#    'Robert_B._Pippin',
#    'Jakob_Friedrich_Fries',
#    'Alenka_Zupančič',
#    'Ralf_Dahrendorf__yes__1',
#    'Martin_Gardner__Plato,_Kant,_G._K._Chesterton,_William_James,_Char__1',
#    'Georg_Simmel',
#    'Dewi_Zephaniah_Phillips',
#    'F._H._Jacobi',
#    'William_Desmond_(philosopher)',
#    'A._J._Ayer',
#    'Victor_Cousin',
#    'Bernard_Bolzano',
#    'Richard_Avenarius',
#    'Jean_Piaget',
#    'Alfred_North_Whitehead',
#    'T._K._Seung',
#    'Tyler_Burge',
#    'Joxe_Azurmendi',
#    'M._Hiriyanna',
#    'Johann_Gottfried_Herder',
#    'Michael_Sandel',
#    'Johann_Gottlieb_Fichte',
#    'Reinhart_Koselleck',
#    'Jean-Marie_Guyau',
#    'Susan_Neiman',
#    'Max_Horkheimer',
#    'Otto_Weininger',
#    'Nicholas_Rescher',
#    'Harry_Frankfurt',
#    'Ady_Jean-Gardy',
#    'R._G._Collingwood',
#    'Moritz_Schlick',
#    'Helmut_Wautischer',
#    'Vittorio_Hösle',
#    'Ted_Cohen_(philosopher)',
#    'Odo_Marquard',
#    'Martin_Buber',
#    'Wilhelm_Windelband',
#    'Traian_Brăileanu',
#    'Michel_Aflaq__1',
#    'Bryan_Magee',
#    'Friedrich_Albert_Lange',
#    'Mladen_Dolar',
#    'Wilhelm_Wundt',
#    'Catherine_Malabou',
#    'F._H._Bradley',
#    'Jordi_Pigem',
#    'Gilles_Deleuze',
#    'Salomon_Maimon',
#    'Karl_Korsch',
#    'Alphonso_Lingis',
#    'Theodor_W._Adorno',
#    'Georg_Wilhelm_Friedrich_Hegel',
#    'Nick_Land',
#    'Derek_Parfit',
#    'Predrag_Finci',
#    'R._M._Hare',
#    'Friedrich_Schleiermacher',
#    'Nicolai_Hartmann',
#    'Friedrich_Heinrich_Jacobi',
#    'Charles_Sanders_Peirce',
#    'Stephen_Darwall',
#    'Wilhelm_Dilthey',
#    'Karl_Popper',
#    'Mário_Ferreira_dos_Santos',
#    'Simon_Glendinning',
#    'Gustav_Fechner',
#    'Karl_Christian_Friedrich_Krause',
#    'Umberto_Eco',
#    'Robert_Adamson_(philosopher)',
#    'Emil_Fackenheim',
#    'Louis_Arnaud_Reid'],
#   'Léon_Brunschvicg': ['Hélène_Metzger',
#    'Gaston_Bachelard',
#    'Louis_Lavelle',
#    'Jean_Cavaillès',
#    'Alexandre_Koyré',
#    'Étienne_Gilson',
#    'Raymond_Aron'],
#   'Jane_Addams': ['Patricia_M._Shields'],
#   'Iamblichus': ['Aedesius', 'Proclus', 'Pseudo-Dionysius_the_Areopagite'],
#   'Hu_Shih': ['Gu_Jiegang'],
#   'Émile_Meyerson': ['Thomas_Kuhn', 'Gaston_Bachelard', 'Hélène_Metzger'],
#   'Nick_Land': ['Kodwo_Eshun',
#    'Iain_Hamilton_Grant',
#    'Ray_Brassier',
#    'Dark_Enlightenment',
#    'Reza_Negarestani',
#    'Mark_Fisher',
#    'Kode9'],
#   'Nicole_Oresme': ['Galileo_Galilei',
#    'Henry_of_Langenstein',
#    'Gilles_Châtelet'],
#   'Alexandre_Koyré': ['Hélène_Metzger',
#    'Alexandre_Kojève',
#    'Abdel_Rahman_Badawi',
#    'Thomas_Kuhn',
#    'Nader_El-Bizri',
#    'Paul_Feyerabend'],
#   'Antonin_Sertillanges': ['Mário_Ferreira_dos_Santos'],
#   'George_Holmes_Howison': ['William_Henry_Chamberlin_(philosopher)'],
#   'Nikolai_Chernyshevsky': ['Svetozar_Marković'],
#   'Jean_Cavaillès': ['Jules_Vuillemin',
#    'Gilles-Gaston_Granger',
#    'Georges_Canguilhem',
#    'Louis_Althusser',
#    'Jean_Hyppolite'],
#   'Giacomo_Leopardi': ['Philipp_Mainländer',
#    'Arthur_Schopenhauer',
#    'Friedrich_Nietzsche',
#    'Carlo_Michelstaedter',
#    'Samuel_Beckett',
#    'Giosuè_Carducci',
#    'Albert_Camus',
#    'Miguel_de_Unamuno',
#    'Umberto_Saba',
#    'Francesco_De_Sanctis'],
#   'Anicius_Manlius_Severinus_Boethius': ['Peter_Abelard',
#    'John_Scotus_Eriugena'],
#   'William_Pepperell_Montague': ['Brand_Blanshard'],
#   'Carl_Linnaeus': ['Fredrik_Hasselqvist', 'Antonio_José_Cavanilles'],
#   'Pierre_Paul_Royer-Collard': ['Victor_Cousin'],
#   'Baruch_Spinoza': ['Erich_Fromm',
#    'Kiarina_Kordela',
#    'Johann_Gottfried_Herder',
#    'John_Locke',
#    'Friedrich_Wilhelm_Joseph_Schelling',
#    'Ludwig_Wittgenstein',
#    'Michael_Oakeshott',
#    'Johann_Gottlieb_Fichte',
#    'Charles_Renouvier',
#    'Albert_Einstein',
#    'Irvin_D._Yalom',
#    'Karl_Heinrich_Marx',
#    'Slavoj_Žižek',
#    'Novalis',
#    'Branislav_Petronijević',
#    'Samuel_Taylor_Coleridge',
#    'Miguel_de_Unamuno',
#    'Richard_Popkin',
#    'Errol_Harris',
#    'Arthur_Schopenhauer',
#    'Jean-Jacques_Rousseau',
#    'Georgi_Plekhanov',
#    'Friedrich_Nietzsche',
#    'Simone_Weil',
#    'Karl_Jaspers',
#    'Leo_Strauss',
#    'Gottfried_Leibniz',
#    'Christian_Wolff_(philosopher)',
#    'Emil_Fackenheim',
#    'Gotthold_Ephraim_Lessing',
#    'George_Eliot',
#    'Dimitris_Vardoulakis',
#    'Lenn_E._Goodman',
#    'Johann_Wolfgang_von_Goethe',
#    'François_Zourabichvili',
#    'Gilles_Deleuze',
#    'Johann_Gottfried_von_Herder',
#    'Arne_Næss',
#    'Stuart_Hampshire',
#    'Gabriel_Wagner',
#    'Mark_Fisher',
#    'Thomas_Wizenmann',
#    'Samuel_Alexander',
#    'Rosi_Braidotti',
#    'Pierre_Bayle',
#    'Jane_Bennett_(political_theorist)',
#    'Georg_Wilhelm_Friedrich_Hegel',
#    'Evald_Ilyenkov',
#    'Denis_Diderot',
#    'George_Santayana',
#    'Edgar_Morin',
#    'Joseph_Dietzgen',
#    'Friedrich_Schleiermacher',
#    'Pierre-Sylvain_Régis',
#    'Friedrich_Heinrich_Jacobi',
#    'Enlightenment_philosophy',
#    'Bertrand_Russell',
#    'Sigmund_Freud',
#    'Gottfried_Wilhelm_Leibniz',
#    'George_Boole',
#    'Mário_Ferreira_dos_Santos',
#    'Étienne_Balibar',
#    'Louis_Althusser',
#    'Antonio_Negri',
#    'Quentin_Meillassoux',
#    'Christoph_von_Sigwart',
#    'Lev_Vygotsky',
#    'Fichte',
#    'Leszek_Kołakowski',
#    'Jorge_Luis_Borges',
#    'Michael_Hardt',
#    'Donald_Davidson_(philosopher)',
#    'Costanzo_Preve'],
#   'Thomas_Malthus': ['Charles_Darwin'],
#   'Josiah_Royce': ['Morris_Raphael_Cohen',
#    'Gabriel_Marcel',
#    'C._I._Lewis',
#    'Charles_Hartshorne',
#    'Brand_Blanshard',
#    'Henry_M._Sheffer',
#    'Timothy_Sprigge',
#    'Edward_Vermilye_Huntington',
#    'Clarence_Irving_Lewis',
#    'William_Henry_Chamberlin_(philosopher)',
#    'John_Elof_Boodin',
#    'John_William_Miller',
#    'Curt_John_Ducasse',
#    'Norbert_Wiener',
#    'George_Herbert_Mead',
#    'William_Ernest_Hocking'],
#   'Karl_Polanyi': ['Ayşe_Buğra',
#    'Immanuel_Wallerstein',
#    'Herman_Daly',
#    'David_Graeber',
#    'Giovanni_Arrighi',
#    'John_Gray_(philosopher)',
#    'Mark_Blyth',
#    'Nancy_Fraser',
#    'Regulation_school',
#    'Tom_Malleson',
#    'Joseph_Stiglitz',
#    'Jacob_Hacker',
#    'Peter_Drucker',
#    'Dani_Rodrik',
#    'Takis_Fotopoulos',
#    'Murray_Bookchin',
#    'Moses_Finley',
#    'Fred_L._Block',
#    'Daniel_Bell',
#    'Marshall_Sahlins',
#    'Kari_Polanyi_Levitt',
#    'Ira_Katznelson',
#    'James_C._Scott',
#    'Margaret_Somers',
#    'Arthur_Koestler',
#    'Andy_Sumner',
#    'Herbert_Gintis',
#    'Samuel_Bowles_(economist)',
#    'Robin_Hahnel',
#    'Mark_Granovetter'],
#   'Ralph_Barton_Perry': ['C._I._Lewis',
#    'Henry_Nelson_Wieman',
#    'Paul_Weiss_(philosopher)',
#    'Joel_Feinberg',
#    'Donald_Cary_Williams',
#    'William_Frankena'],
#   'Duns_Scotus__John_Duns_Scotus__1': ['Alvin_Plantinga',
#    'René_Descartes',
#    'Antonius_Andreas',
#    'Mário_Ferreira_dos_Santos',
#    'Martin_Heidegger',
#    'Henry_Harclay',
#    'William_of_Ockham',
#    'Thomas_Wilton',
#    'Hannah_Arendt',
#    'Charles_Sanders_Peirce',
#    'Gilles_Deleuze',
#    'Gerard_Manley_Hopkins'],
#   'Julia_Kristeva': ['Noëlle_McAfee'],
#   'Jean-Baptiste_Lamarck': ['William_Healey_Dall',
#    'Johann_Friedrich_Meckel',
#    'Herbert_Spencer',
#    'William_McDougall_(psychologist)',
#    'Charles_Lyell',
#    'Florentino_Ameghino',
#    'Nikolay_Chernyshevsky',
#    'Étienne_Geoffroy_Saint-Hilaire'],
#   'Otto_Liebmann': ['Gottlob_Frege', 'Benno_Kerry'],
#   'Wolfgang_Smith': ['Olavo_de_Carvalho'],
#   'Hugo_Grotius': ['Christian_Thomasius',
#    'Gottfried_Wilhelm_Leibniz',
#    'Jean-Jacques_Rousseau',
#    'Jean_Barbeyrac',
#    'John_Locke',
#    'John_Milton',
#    'Giambattista_Vico',
#    'Gustavus_Adolphus_of_Sweden',
#    'Tara_Smith_(philosopher)',
#    'Cornelius_van_Bynkershoek',
#    'Thomas_Hobbes',
#    'Tibor_Machan',
#    'Richard_Cumberland_(philosopher)',
#    'Robert_Filmer',
#    'Samuel_von_Pufendorf',
#    'Baruch_Spinoza',
#    'John_Selden'],
#   'Fred_Newman_(philosopher)': ['Lois_Holzman', 'Lenora_Fulani'],
#   'Timon_of_Phlius': ['Arcesilaus',
#    'Aenesidemus',
#    'Agrippa_the_Skeptic',
#    'Sextus_Empiricus'],
#   'Crispin_Wright': ['Carrie_Ichikawa_Jenkins',
#    'Duncan_Pritchard',
#    'Michael_Lynch_(philosopher)',
#    'Luca_Moretti',
#    'Michael_P._Lynch',
#    'Paul_Boghossian',
#    'Annalisa_Coliva',
#    'Neil_Tennant_(philosopher)',
#    'Jose_Zalabardo'],
#   'Louis_Althusser': ['Philippe-Joseph_Salazar',
#    'Judith_Butler',
#    'Michel_Foucault',
#    'Terry_Eagleton',
#    'Benny_Lévy',
#    'Richard_D._Wolff',
#    'Roy_Bhaskar',
#    'Amina_Mama',
#    'Jacques_Rancière',
#    'Gilles_Deleuze',
#    'Mahdi_Amel',
#    'Bernard-Henri_Lévy',
#    'Nicos_Poulantzas',
#    'Stephen_Resnick',
#    'Duncan_K._Foley',
#    'Jack_Amariglio',
#    'Paul_R._Patton',
#    'Rey_Chow',
#    'Bruce_Lincoln',
#    'Jean-Luc_Marion',
#    'G._A._Cohen'],
#   'Roscoe_Pound': ['Zechariah_Chafee'],
#   'George_Henry_Lewes': ['Alexander_Bain', 'Herbert_Spencer'],
#   'T._H._Green': ['J._M._E._McTaggart',
#    'Samuel_Alexander',
#    'J._H._Muirhead',
#    'C._B._Macpherson',
#    'John_Dewey',
#    'Hastings_Rashdall',
#    'John_Cook_Wilson',
#    'F._H._Bradley',
#    'R._L._Nettleship',
#    'David_George_Ritchie',
#    'Leonard_Hobhouse'],
#   'Eino_Kaila': ['Georg_Henrik_von_Wright'],
#   'Franz_Xaver_von_Baader': ['Nikolai_Berdyaev'],
#   'William_James': ['Milič_Čapek',
#    'Joseph_A._Bracken',
#    'Mookie_Tenembaum',
#    'Ludwig_Wittgenstein',
#    'Brian_Massumi',
#    'Donald_A._Crosby',
#    'James_M._Edie',
#    'C._Wright_Mills',
#    'Richard_Davidson',
#    'Ronald_A._Kuipers',
#    'Jimmy_Carter',
#    'Traian_Brăileanu',
#    'Edmund_Husserl',
#    'Hilary_Putnam',
#    'Antonio_Damasio',
#    'Richard_Rorty',
#    'Julian_Simon',
#    'Curt_John_Ducasse',
#    'W._E._B._Du_Bois',
#    'Jean_Wahl',
#    'Marilynne_Robinson',
#    'Émile_Durkheim',
#    'Josiah_Royce',
#    'Martin_Gardner__Plato,_Kant,_G._K._Chesterton,_William_James,_Char__1',
#    'William_Herbert_Sheldon',
#    'George_Santayana',
#    'Mortimer_J._Adler',
#    'Edward_C._Harwood',
#    'Edward_S._Casey',
#    'John_Dewey',
#    'David_Shakow',
#    'William_Damon',
#    'Henry_Hazlitt',
#    'Morris_Raphael_Cohen',
#    'Bertrand_Russell',
#    'F._C._S._Schiller',
#    'Erin_Manning_(theorist)',
#    'Georges_Sorel',
#    'Gregory_Fernando_Pappas',
#    'Mário_Ferreira_dos_Santos',
#    'Eric_Voegelin',
#    'Henri_Bergson',
#    'John_Daniel_Wild',
#    'Thorstein_Veblen',
#    'Richard_J._Bernstein',
#    'Alfred_Schütz',
#    'B._F._Skinner',
#    'Edwin_Holt',
#    'Gertrude_Stein',
#    'Alfred_North_Whitehead',
#    'Louis_Arnaud_Reid'],
#   'Henrik_Steffens': ['Arnold_Guyot',
#    'Julius_Christian_Braniß',
#    'Immanuel_Hermann_Fichte',
#    'Søren_Kierkegaard'],
#   'Zygmunt_Zawirski': ['Andrzej_Grzegorczyk'],
#   'Nikolai_Fyodorovich_Fyodorov': ['Konstantin_Tsiolkovsky',
#    'Transhumanism',
#    'Vladimir_Vernadsky'],
#   'Mohammed_Abed_al-Jabri': ['Saddek_Rabah'],
#   'Ralph_Cudworth': ['Anthony_Ashley-Cooper,_3rd_Earl_of_Shaftesbury',
#    'Damaris_Cudworth_Masham',
#    'William_Wollaston'],
#   'Friedrich_Waismann': ['H._L._A._Hart', 'Gustav_Bergmann'],
#   'Éric_Geoffroy': ['Ahmed_Bouyerdene'],
#   'Jean-François_Melon': ['Montesquieu',
#    'Voltaire',
#    'Denis_Diderot',
#    'François_Quesnay'],
#   'Karl_Robert_Eduard_von_Hartmann': ['Sigmund_Freud',
#    'Carl_Jung',
#    'Johannes_Rehmke',
#    'Rudolf_Steiner',
#    'Hans_Vaihinger',
#    'Branislav_Petronijević',
#    'Agnes_Taubert',
#    'Arthur_Drews'],
#   'Theodore_George': ['Cynthia_Nielsen'],
#   'Karl-Otto_Apel': ['Jürgen_Habermas',
#    'Vittorio_Hösle',
#    'Hans-Hermann_Hoppe',
#    'Hans_Albert'],
#   'Dominique_Janicaud': ['Simon_Critchley'],
#   'Adolf_Grünbaum': ['Bas_van_Fraassen'],
#   'Aleksei_Losev': ['Alexander_Dobrokhotov'],
#   'Sara_Ruddick': ['Margaret_Urban_Walker'],
#   'Ludovico_Geymonat': ['Evandro_Agazzi', 'Mario_Vegetti'],
#   'Jacob_Moleschott': ['Edmund_Montgomery', 'Ivan_Pavlov'],
#   'Edvard_Westermarck': ['Bronisław_Malinowski'],
#   'Martin_Luther': ['Reinhart_Koselleck',
#    'Søren_Kierkegaard',
#    'Johann_Georg_Hamann'],
#   'Dugald_Stewart': ['James_Mill'],
#   'T._S._Eliot': ['Russell_Kirk'],
#   'Ernest_Sosa': ['Brie_Gertler', 'John_Greco_(philosopher)'],
#   'Hélène_Metzger': ['Thomas_Kuhn', 'Gaston_Bachelard'],
#   'Richard_FitzRalph': ['John_Wycliffe'],
#   'Adolfo_Sánchez_Vázquez': ['Bolívar_Echeverría'],
#   'Vladimir_Solovyov_(philosopher)': ['Nikolay_Lossky',
#    'Aleksei_Losev',
#    'Boris_Groys',
#    'Alexandre_Kojève',
#    'Dostoyevsky',
#    'Andrei_Belyi',
#    'Sergey_Bulgakov',
#    'Pavel_Florensky',
#    'Nikolai_Berdyaev',
#    'Semyon_Frank',
#    'Alexander_Blok',
#    'Nicolas_Berdyaev'],
#   'Amina_Wadud': ['Michael_Muhammad_Knight', 'Asra_Nomani'],
#   'John_McDowell': ['Alice_Crary',
#    'Louise_Antony',
#    'Sally_Sedgwick',
#    'Robert_B._Pippin',
#    'Miranda_Fricker',
#    'Robert_Brandom',
#    'Hilary_Putnam',
#    'Axel_Honneth',
#    'Jonathan_Dancy'],
#   'Martin_Gardner__Plato,_Kant,_G._K._Chesterton,_William_James,_Char__1': ['Ian_Stewart_(mathematician)',
#    'Douglas_Hofstadter',
#    'John_Horton_Conway',
#    'Donald_Knuth',
#    'James_Randi',
#    'Erik_Demaine',
#    'Michael_Shermer',
#    'Dennis_Shasha',
#    'Raymond_Smullyan',
#    'Ronald_Graham',
#    'Ray_Hyman',
#    'Persi_Diaconis',
#    'Marvin_Minsky'],
#   'Taha_Hussein': ['Naguib_Mahfouz', 'Tahar_Ben_Jelloun'],
#   'Pierre-Simon_Laplace': ['Adolphe_Quetelet'],
#   'Hermann_Lotze': ['Bertrand_Russell',
#    'Bernard_Bosanquet_(philosopher)',
#    'George_Trumbull_Ladd',
#    'Josiah_Royce',
#    'Hermann_Helmholtz',
#    'Wilhelm_Windelband',
#    'Rudolf_Christoph_Eucken',
#    'Edmund_Husserl',
#    'Borden_Parker_Bowne',
#    'William_James',
#    'Gottlob_Frege',
#    'Thomas_Hill_Green',
#    'F._H._Bradley',
#    'James_Ward_(psychologist)',
#    'Branislav_Petronijević',
#    'Georg_Elias_Müller',
#    'Carl_Stumpf'],
#   'Arne_Næss': ['David_Orton_(deep_ecology)'],
#   'Jean_Philibert_Damiron': ["Domingo_Faustino_Sarmiento__Generation_of_'37,_The_Federalist,_Babeuf,_Bello,__1"],
#   'Bernard_Loomer': ['Nancy_Frankenberry'],
#   'Bruno_de_Finetti': ['Isaac_Levi', 'Nicola_Acocella'],
#   'Regine_Olsen': ['Søren_Kierkegaard'],
#   'Julien_Offray_de_La_Mettrie': ['Michel_Onfray', 'François_Picavet'],
#   'Ion_Dragoumis': ['Nikos_Kazantzakis',
#    'Dimitris_Pikionis',
#    'Penelope_Delta',
#    'Georgios_Grivas',
#    'Kostis_Palamas',
#    'Angelos_Sikelianos',
#    'Odysseas_Elytis',
#    'Renos_Apostolidis',
#    'Andreas_Papandreou',
#    'Pavlos_Melas'],
#   'Félix_Guattari': ['Erin_Manning_(theorist)',
#    'Jasbir_Puar',
#    'Brian_Massumi',
#    'Reza_Negarestani',
#    'Bryan_Reynolds_(scholar)',
#    'Michael_Hardt',
#    'Antonio_Negri',
#    'Gilles_Deleuze',
#    'Mark_Fisher'],
#   'Max_Scheler': ['Edith_Stein',
#    'Viktor_Frankl',
#    'Karol_Wojtyła',
#    'Ortega_y_Gasset',
#    'Mário_Ferreira_dos_Santos',
#    'Martin_Heidegger',
#    'Erich_Przywara',
#    'José_Ortega_y_Gasset',
#    'Mikhail_Bakhtin',
#    'Dietrich_von_Hildebrand',
#    'Alberto_Buela',
#    'Nicolai_Hartmann',
#    'Martin_Buber',
#    'Eugène_Minkowski',
#    'Kurt_Mueller-Vollmer'],
#   'Henri_Bergson': ['Nikos_Kazantzakis',
#    'Renaud_Barbaras',
#    'Milič_Čapek',
#    'José_Ortega_y_Gasset',
#    'Brian_Massumi',
#    'Gilbert_Simondon',
#    'Émile_Bréhier',
#    'Jean_Gebser',
#    'Vladimir_Jankélévitch',
#    'Anna-Teresa_Tymieniecka',
#    'Pierre_Teilhard_de_Chardin',
#    'Georges_Canguilhem',
#    'Édouard_Le_Roy',
#    'Michel_Aflaq__1',
#    'Wyndham_Lewis',
#    'Jacques_Maritain',
#    'Roy_Ascott',
#    'Necip_Fazıl_Kısakürek',
#    'Yasuo_Yuasa',
#    'François_Simiand',
#    'Gilles_Deleuze',
#    'Ghislain_Deslandes',
#    'Michel_Aflaq',
#    'Jawaharlal_Nehru',
#    'Jean_Wahl',
#    'Simone_de_Beauvoir',
#    'Maurice_Merleau-Ponty',
#    'Muhammad_Iqbal',
#    'Alexandre_Koyré',
#    'Henry_Nelson_Wieman',
#    'Jane_Bennett_(political_theorist)',
#    'Emmanuel_Mounier',
#    'Ilya_Prigogine',
#    'Eugène_Minkowski',
#    'Jean-Paul_Sartre',
#    'Emmanuel_Levinas',
#    'Alfred_North_Whitehead',
#    'Gabriel_Marcel',
#    'Keiji_Nishitani',
#    'Georges_Sorel',
#    'Eric_Voegelin',
#    'Pierre_Hadot',
#    'Quentin_Meillassoux',
#    'Jean-Luc_Marion',
#    'Alfred_Schütz',
#    'Guy_Debord',
#    'Marcel_Proust',
#    'Liang_Shuming',
#    'Zaki_al-Arsuzi',
#    'Jean_Piaget',
#    'Max_Scheler',
#    'Henry_Miller',
#    'Louis_Arnaud_Reid'],
#   'Ramakrishna': ['Helena_Roerich'],
#   'George_Boole': ['Hugh_MacColl',
#    'Augustus_De_Morgan',
#    'William_Stanley_Jevons',
#    'Victor_Shestakov',
#    'Claude_Shannon',
#    'John_Maynard_Keynes',
#    'William_Ernest_Johnson',
#    'Charles_Sanders_Peirce'],
#   'Pāṇini': ['Leonard_Bloomfield', 'Franz_Bopp', 'Ferdinand_de_Saussure'],
#   'Sextus_Empiricus': ['Luciano_Floridi',
#    'Francisco_Sanches',
#    'Pierre_Charron',
#    'René_Descartes',
#    'Friedrich_Nietzsche',
#    'Michel_de_Montaigne',
#    'Descartes',
#    'Nassim_Taleb',
#    'Edmund_Husserl',
#    'Georg_Wilhelm_Friedrich_Hegel',
#    'Immanuel_Kant',
#    'David_Hume'],
#   "Ibn_Mada'": ['Abu_Hayyan_Al_Gharnati'],
#   'Thomas_Reid': ['Alvin_Plantinga',
#    'Charles_Hodge',
#    'George_Elder_Davie',
#    'Mookie_Tenembaum',
#    'Sir_William_Hamilton,_9th_Baronet',
#    'Arthur_Schopenhauer',
#    'Michael_Bergmann_(philosopher)',
#    'Nicholas_Wolterstorff',
#    'G._E._Moore',
#    'Keith_Lehrer',
#    'Brian_Glenney',
#    'James_Frederick_Ferrier',
#    'Keith_DeRose',
#    'William_Alston',
#    'John_Haldane_(philosopher)',
#    'Michael_Huemer',
#    'Ernest_Renan',
#    'Dugald_Stewart',
#    'Friedrich_Heinrich_Jacobi',
#    'Charles_Sanders_Peirce',
#    'David_Hartley_(philosopher)',
#    'William_James',
#    'Mylan_Engel',
#    'Victor_Cousin',
#    'James_Beattie_(poet)',
#    'George_Campbell_(minister)',
#    'William_L._Rowe',
#    'Roderick_Chisholm'],
#   'Dietrich_von_Hildebrand': ['Pope_Benedict_XVI',
#    'Peter_Kreeft',
#    'Alice_von_Hildebrand'],
#   'R._B._Braithwaite': ['Stephen_Toulmin',
#    'Imre_Lakatos',
#    'Georg_Henrik_von_Wright'],
#   'Mikhail_Bakunin': ['Noam_Chomsky',
#    'Georgi_Plekhanov',
#    'Karl_Korsch',
#    'Antonio_Escohotado',
#    'Errico_Malatesta',
#    'Peter_Kropotkin',
#    'Carlo_Cafiero',
#    'John_Zerzan',
#    'Emma_Goldman',
#    'Daniel_Guérin',
#    'Sergei_Nechaev'],
#   'Mitrofan_Lodyzhensky': ['Leo_Tolstoy', 'P._D._Ouspensky'],
#   'Jakob_Schegk': ['Nicolaus_Taurellus', 'Second_scholasticism'],
#   'Jean-François_Lyotard': ['Gregg_Lambert',
#    'Douglas_Kellner',
#    'Richard_Rorty',
#    'Bracha_L._Ettinger',
#    'Jacques_Rancière'],
#   'Adolf_Reinach': ['Dietrich_von_Hildebrand', 'Barry_Smith_(ontologist)'],
#   'Ernest_Nagel': ['Douglas_Hofstadter',
#    'Isaac_Levi',
#    'Patrick_Suppes',
#    'Mario_Bunge',
#    'Henry_Kyburg'],
#   'John_Anderson_(philosopher)': ['Eugene_Kamenka',
#    'David_Malet_Armstrong',
#    'J._L._Mackie',
#    'John_Passmore',
#    'David_Stove',
#    'Hedley_Bull',
#    'A._J._Baker'],
#   'Hadi_Sabzavari': ['Muhammad_Husayn_Tabatabai'],
#   'Asa_Gray': ['Wilhelm_Nikolaus_Suksdorf',
#    'William_Brackenridge',
#    'William_Conklin_Cusick',
#    'Liberty_Hyde_Bailey',
#    'Thomas_Meehan_(botanist)'],
#   'Jonathan_Dancy': ['Constantine_Sandis'],
#   'Meher_Baba': ['Danese_Cooper', 'Gadge_Maharaj'],
#   'John_Mearsheimer': ['Robert_D._Kaplan'],
#   'Greg_Bahnsen': ['R.J._Rushdoony',
#    'Francis_Schaeffer',
#    'John_Frame_(theologian)'],
#   'Mladen_Dolar': ['Slavoj_Žižek', 'Alenka_Zupančič'],
#   'Euclid_of_Megara': ['Eubulides',
#    'Thrasymachus_of_Corinth',
#    'Stilpo',
#    'Ichthyas',
#    'Clinomachus'],
#   'Carlo_Michelstaedter': ['Claudio_Magris', 'Julius_Evola', 'Aldo_Capitini'],
#   'Diogenes_of_Sinope': ['Mookie_Tenembaum', 'Crates_of_Thebes', 'Han_Ryner'],
#   'Thomas_Paine': ['Charles_Darwin',
#    'Moncure_D._Conway',
#    'Thomas_Jefferson',
#    'George_Carlin',
#    'Christopher_Hitchens',
#    'William_Godwin',
#    'Friedrich_Nietzsche',
#    'Thomas_Edison',
#    'Bill_Maher',
#    'Karl_Marx',
#    'Pierre_Victurnien_Vergniaud',
#    'Milton_Friedman',
#    'Mark_Twain',
#    'Syed_Ahmad_Khan',
#    'Jyotirao_Phule',
#    'Bertrand_Russell',
#    'Mary_Wollstonecraft',
#    'Sigmund_Freud',
#    'Thorstein_Veblen',
#    'Robert_G._Ingersoll',
#    'Abraham_Lincoln'],
#   'David_Pears': ['Derek_Parfit'],
#   'Bernard_Williams': ['Ted_Honderich',
#    'Martha_Nussbaum',
#    'Robert_B._Pippin',
#    'Alan_Thomas_(philosopher)',
#    'Susan_R._Wolf',
#    'Miranda_Fricker',
#    'Jeff_McMahan_(philosopher)',
#    'Alastair_Hannay',
#    'Raymond_Geuss'],
#   'Jakob_Friedrich_Fries': ['Otto_Fritz_Meyerhof',
#    'Karl_Popper',
#    'Leonard_Nelson',
#    'Hermann_Lotze'],
#   'Milan_Komar': ['Alojz_Rebula', 'Zorko_Simčič', 'Augusto_del_Noce'],
#   'William_Blake': ['Joseph_Webb',
#    'Arild_Rosenkrantz',
#    'Melinda_Camber_Porter'],
#   'John_Wycliffe': ['John_Calvin',
#    'Martin_Luther',
#    'Huldrych_Zwingli',
#    'Petr_Chelčický',
#    'Paul_of_Venice',
#    'Jan_Hus',
#    'William_Tyndale',
#    'Henry_VIII'],
#   'Henry_David_Thoreau': ['John_Muir',
#    'E._B._White',
#    'John_F._Kennedy',
#    'Emma_Goldman',
#    'Sinclair_Lewis',
#    'Gene_Sharp',
#    'Martin_Luther_King_Jr.',
#    'Mahatma_Gandhi',
#    'George_Bernard_Shaw',
#    'Upton_Sinclair',
#    'Glenn_Gould',
#    'John_Zerzan',
#    'Loren_Eiseley',
#    'Stanley_Cavell',
#    'Christopher_McCandless',
#    'Jane_Bennett_(political_theorist)',
#    'Ernest_Hemingway',
#    'Walt_Whitman',
#    'W._B._Yeats',
#    'Louis_Blanc',
#    'Leo_Tolstoy',
#    'E._O._Wilson',
#    'Marcel_Proust',
#    'Bob_Black',
#    'B._F._Skinner'],
#   'Paul_Guyer': ['R._Lanier_Anderson_(philosopher)',
#    'Allen_W._Wood',
#    'Ted_Cohen_(philosopher)'],
#   'Sissela_Bok': ['Anita_L._Allen'],
#   'Gianni_Vattimo': ['Mario_Kopić',
#    'Peter_Carravetta',
#    'Santiago_Zabala',
#    'Stefan_Lorenz_Sorgner',
#    'Maurizio_Ferraris',
#    'Richard_Rorty',
#    'Diego_Bubbio',
#    'Lorenzo_Ferrero',
#    'Ghislain_Deslandes'],
#   'Adam_Smith': ['James_Watt',
#    'Martha_Nussbaum',
#    'Mookie_Tenembaum',
#    'Shirzad_Peik_Herfeh',
#    'Immanuel_Kant',
#    'Glen_Pettigrove',
#    'George_Grantham_(economic_historian)',
#    'Friedrich_Hayek',
#    'Nikolay_Chernyshevsky',
#    'Joan_Robinson',
#    'Karl_Polanyi',
#    'James_Otteson',
#    'David_D._Friedman',
#    'Tom_Campbell_(philosopher)',
#    'Robert_Sugden_(economist)',
#    'Henri_de_Saint-Simon',
#    'Christian_Jakob_Kraus',
#    'Léon_Walras',
#    'Donald_J._Boudreaux',
#    'Frédéric_Bastiat',
#    'Juan_Bautista_Alberdi',
#    'Julian_Simon',
#    'Armen_Alchian',
#    'David_R._Henderson',
#    'David_Hume',
#    'Thomas_Hodgskin',
#    'J._Bradford_DeLong',
#    'Milton_Friedman',
#    'John_Ramsay_McCulloch',
#    'Thomas_Piketty',
#    'Russ_Roberts',
#    'Éric_Pichet',
#    'Georg_Wilhelm_Friedrich_Hegel',
#    'Pierre-Joseph_Proudhon',
#    'Carl_Menger',
#    'Jeremy_Bentham',
#    'Friedrich_Heinrich_Jacobi',
#    'Jean_Charles_Léonard_de_Sismondi',
#    'Antonio_Rosmini',
#    'Jean-Baptiste_Say',
#    'Mark_Skousen',
#    'George_Reisman',
#    'Steven_N._S._Cheung',
#    'Edward_Atkinson_(activist)',
#    'Nassau_William_Senior',
#    'Fernando_Vianello',
#    'Amartya_Sen'],
#   'Ludwig_Binswanger': ['Laurence_A._Rickels',
#    'Franco_Basaglia',
#    'Medard_Boss',
#    'Jürgen_Habermas',
#    'Eugène_Minkowski'],
#   'Jean-Pierre_de_Crousaz': ['Edward_Gibbon'],
#   'Pietro_Pomponazzi': ['Lucilio_Vanini'],
#   'Stéphane_Lupasco': ['Mário_Ferreira_dos_Santos'],
#   'Umberto_Eco': ['Susan_Petrilli', 'Rein_Raud'],
#   'Wilfred_Stein': ['Eric_Barnard',
#    'Antonio_Tito_Fojo',
#    'Michael_M._Gottesman',
#    'Michael_Lanzer',
#    'Susan_Bates',
#    'Igor_Roninson',
#    'Suresh_Ambudkar',
#    'Hagai_Ginsburg',
#    'Lewis_Wolpert',
#    'Thomas_Litman',
#    'Thomas_Zeuthen',
#    'Steven_Karlish'],
#   'Derek_Parfit': ['Brad_Hooker',
#    'Peter_Singer',
#    'Ruth_Chang',
#    'Thomas_Hurka',
#    'Toby_Ord',
#    'John_Cottingham',
#    'William_MacAskill',
#    'Samuel_Scheffler',
#    'Jeff_McMahan_(philosopher)',
#    'Larry_Temkin'],
#   'Sadie_Plant': ['Mark_Fisher'],
#   'Giordano_Bruno': ['James_Joyce',
#    'Gottfried_Wilhelm_Leibniz',
#    'Arthur_Schopenhauer',
#    'Galileo_Galilei',
#    'Molière',
#    'Baruch_Spinoza'],
#   'Josef_Breuer': ['Sigmund_Freud'],
#   'Bernard_Bosanquet_(philosopher)': ['Donald_Cary_Williams',
#    'Brand_Blanshard'],
#   'Ludwik_Fleck': ['Thomas_Kuhn'],
#   'Noam_Chomsky': ['Dan_Sperber',
#    'John_Searle',
#    'Andrew_Radford_(linguist)',
#    'Stevan_Harnad',
#    'John_Grinder',
#    'Andrew_Carnie',
#    'Edward_Said',
#    'Crispin_Wright',
#    'Gilbert_Harman',
#    'Davor_Džalto',
#    'Pierre_Pica',
#    'Ray_C._Dougherty',
#    'James_D._McCawley',
#    'Stephen_Neale',
#    'Peter_Ludlow',
#    'John_M._Carroll_(information_scientist)',
#    'Dada_Maheshvarananda'],
#   'Susan_Haack': ['Luciano_Floridi', 'John_Zeis'],
#   'Leonard_Nelson': ['Kurt_Grelling', 'Minna_Specht', 'Paul_Bernays'],
#   'Johannes_Rehmke': ['Rudolf_Steiner'],
#   'Raymond_Aron': ['Allan_Bloom',
#    'Pierre_Bourdieu',
#    'Tony_Judt',
#    'Pierre_Manent',
#    'Marcel_Gauchet',
#    'Henry_Kissinger',
#    'José_Guilherme_Merquior',
#    'Jean-François_Revel',
#    'Edward_Shils',
#    'Dimitris_Dimitrakos',
#    'Paul_Veyne',
#    'Zbigniew_Brzezinski'],
#   'Seneca_the_Younger': ['Augustine_of_Hippo',
#    'Tertullian',
#    'Giovanni_Colonna_(cardinal,_1295–1348)',
#    'Dante_Alighieri',
#    'Michel_de_Montaigne',
#    'Nassim_Nicholas_Taleb',
#    'Marcus_Aurelius',
#    'Boethius',
#    'Tibor_Machan',
#    'Martin_of_Braga',
#    'Baltasar_Gracián',
#    'Medieval_philosophy',
#    'Albertino_Mussato',
#    'Giovanni_Reale'],
#   'Hilary_Putnam': ['Tyler_Burge',
#    'Ned_Block',
#    'David_Kellogg_Lewis',
#    'Martha_Nussbaum',
#    'George_Boolos',
#    'Jerry_Fodor',
#    'Hartry_Field',
#    'Paul_Benacerraf',
#    'Norman_Daniels',
#    'Lawrence_Sklar',
#    'Richard_Boyd',
#    'Saul_Kripke',
#    'David_Marr_(psychologist)',
#    'Daniel_Dennett',
#    'Roberto_Torretti',
#    'Donald_Davidson_(philosopher)',
#    'John_Worrall_(philosopher)'],
#   'Herbert_Spencer': ['Francisco_Antonio_Encina',
#    'Charles_Darwin',
#    'Jean-Marie_Guyau',
#    'Vilfredo_Pareto',
#    'John_Fiske_(philosopher)',
#    'Friedrich_Nietzsche',
#    'Butler_D._Shaffer',
#    'Edward_Abramowski',
#    'Émile_Durkheim',
#    'Murray_Rothbard',
#    'Henry_Sidgwick',
#    'Jack_London',
#    'William_Graham_Sumner',
#    'Henry_Hazlitt',
#    'Guillaume_Faye',
#    'Georges_Vacher_de_Lapouge',
#    'Henri_Bergson',
#    'Thorstein_Veblen',
#    'Jorge_Luis_Borges',
#    'Gustave_Le_Bon'],
#   'Anaximenes_of_Miletus': ['Heraclitus'],
#   'Benno_Kerry': ['Edmund_Husserl', 'Gottlob_Frege', 'Kazimierz_Twardowski'],
#   'Clarence_Irving_Lewis': ['Nelson_Goodman',
#    'Willard_Van_Orman_Quine',
#    'Brand_Blanshard',
#    'Wilfrid_Sellars',
#    'Roderick_Chisholm'],
#   'Edgar_Morin': ['Mara_Selvini_Palazzoli', 'Bernard_Bernier'],
#   'Murray_Bookchin': ['Abdullah_Öcalan',
#    'John_Zerzan',
#    'Rojava_Revolution',
#    'David_Harvey'],
#   'Morris_Raphael_Cohen': ['Sidney_Hook', 'Ernest_Nagel'],
#   'Bernard_Stiegler': ['Daniel_Ross_(philosopher)'],
#   'Arthur_Danto': ['Davor_Džalto',
#    'Noël_Carroll',
#    'David_Carrier',
#    'George_Dickie_(philosopher)'],
#   'Nikolai_Bukharin': ['Duncan_K._Foley'],
#   'Edward_Shils': ['Jerzy_Zubrzycki',
#    'Saul_Bellow',
#    'Joseph_Epstein_(writer)',
#    'Talcott_Parsons',
#    'James_Burk'],
#   'Auguste_Comte': ['Émile_Littré',
#    'Pierre_Laffitte',
#    'John_Stuart_Mill',
#    'Ion_Dragoumis',
#    'Cesare_Lombroso',
#    'Charles_Darwin',
#    'Herbert_Spencer',
#    'Nikolay_Chernyshevsky',
#    'Theophilos_Kairis',
#    'Vilfredo_Pareto',
#    'Gaston_Bachelard',
#    'Friedrich_Nietzsche',
#    'Edward_Spencer_Beesly',
#    'Leo_Strauss',
#    'Karl_Marx',
#    'Michel_Aflaq__1',
#    'George_Henry_Lewes',
#    'Harriet_Martineau',
#    'Émile_Durkheim',
#    'Eugen_Dühring',
#    'Théodule-Armand_Ribot',
#    'Saul_Alves_Martins',
#    'Frederic_Harrison',
#    'Sigmund_Freud',
#    'Émile_Meyerson',
#    'Vladimir_Solovyov_(philosopher)',
#    'Vasile_Pogor',
#    'Charles_Maurras',
#    'Étienne_Gilson',
#    'Alexander_Bain'],
#   'Bas_van_Fraassen': ['Alvin_Plantinga',
#    'Arthur_Fine',
#    'Michael_Rea',
#    'Elisabeth_Lloyd',
#    'Hans_Halvorson',
#    'Nancy_Cartwright_(philosopher)'],
#   'Benjamin_Peirce': ['Charles_Sanders_Peirce'],
#   'Pierre_Hadot': ['Michel_Foucault', 'Arnold_Davidson', 'Wayne_Hankey'],
#   'Paul_Churchland': ['Patricia_Churchland', 'Ray_Brassier'],
#   'Boethius': ['Pope_Benedict_XVI__Joseph_Aloisius_Ratzinger__1',
#    'Anselm_of_Canterbury',
#    'Thomas_Aquinas__Thomas_Aquinas__1',
#    'Peter_Abelard',
#    'Marguerite_Porete',
#    'Thomas_Aquinas',
#    'Medieval_philosophy',
#    'Dante_Alighieri',
#    'Albertus_Magnus'],
#   'Christoph_Gottfried_Bardili': ['Karl_Leonhard_Reinhold'],
#   'Paul_R._Patton': ['Moira_Gatens'],
#   'Denise_Paulme': ['Marcel_Mauss'],
#   'John_Colet': ['Desiderius_Erasmus'],
#   'H._Richard_Niebuhr': ['William_H._Poteat'],
#   'Muhammad_al-Shaybani': ['Isa_ibn_Aban'],
#   'Mulla_Sadra': ['Seyyed_Hossein_Nasr',
#    'Sarmad_Kashani',
#    'Muhammad_Husayn_Tabatabai'],
#   'Ernst_Bloch': ['Jürgen_Moltmann',
#    'Murray_Bookchin',
#    'Theodor_W._Adorno',
#    'Ernesto_Balducci',
#    'Douglas_Kellner',
#    'Fredric_Jameson',
#    'Emmanuel_Levinas'],
#   'Jürgen_Habermas': ['Giles_Hooper',
#    'Thomas_A._McCarthy',
#    'Seyla_Benhabib',
#    'Noëlle_McAfee',
#    'Rainer_Forst',
#    'Nancy_Fraser',
#    'Hans-Hermann_Hoppe',
#    'Ronald_A._Kuipers',
#    'Gordon_Finlayson',
#    'Georg_Henrik_von_Wright',
#    'Iris_Marion_Young',
#    'Michael_Friedman_(philosopher)',
#    'Lauren_Swayne_Barthold',
#    'Omid_Payrow_Shabani',
#    'Guillaume_Faye',
#    'Nicholas_H._Smith',
#    'Nikolas_Kompridis',
#    'Carol_C._Gould',
#    'Claus_Offe',
#    'Richard_J._Bernstein',
#    'Axel_Honneth'],
#   'Emil_du_Bois-Reymond': ['Eduard_Hitzig', 'Julius_Bernstein'],
#   'Marguerite_Porete': ['Christian_mysticism', 'Heresy_of_the_Free_Spirit'],
#   'Laozi': ['Zen',
#    'Dimitrije_Mitrinović',
#    'Chinese_Buddhism',
#    'Mário_Ferreira_dos_Santos',
#    'Martin_Heidegger',
#    'Carl_Jung',
#    'Neotaoism',
#    'Daoism',
#    'Alan_Watts',
#    'Lie_Yukou',
#    'Eastern_philosophy',
#    'René_Guénon',
#    'Zhuang_Zhou'],
#   'Gottlob_Ernst_Schulze': ['Arthur_Schopenhauer', 'Johann_Gottlieb_Fichte'],
#   'Archytas': ['Menaechmus', 'Eudoxus_of_Cnidus'],
#   'Mortimer_J._Adler': ['John_Deely', 'Peter_Kreeft'],
#   'Marcel_Gauchet': ['Judith_Revel'],
#   'Arthur_A._Cohen': ['Thomas_J._J._Altizer'],
#   'Xenocrates': ['Crantor', 'Bion_of_Borysthenes', 'Polemon_(scholarch)'],
#   'Gilbert_Harman': ['Stephen_Stich', 'Joshua_Knobe', 'Jc_Beall'],
#   'Zhu_Xi': ['Sin_Chaeho',
#    'Arthur_Schopenhauer',
#    'Yamazaki_Ansai',
#    'Toegye',
#    'Qian_Mu',
#    'Matsuoka_Shoan',
#    'Wang_Yangming',
#    'Hong_Daeyong',
#    'Bak_Jiwon_(born_1737)',
#    'Tu_Wei-ming',
#    'Joseph_Needham',
#    'Wang_Fuzhi'],
#   'Marin_Mersenne': ['René_Descartes'],
#   'John_Henry_Newman': ['Alvin_Plantinga',
#    'Alasdair_MacIntyre',
#    'Erich_Przywara',
#    "Joseph_S._O'Leary",
#    'Russell_Kirk',
#    'Robert_Barron__List_of_Awards__1'],
#   'Rudolf_von_Jhering': ['Philipp_Heck'],
#   'Alenka_Zupančič': ['Slavoj_Žižek', 'Mladen_Dolar'],
#   'Francisco_Suárez': ['René_Descartes',
#    'Gottfried_Wilhelm_Leibniz',
#    'Gustavo_Bueno',
#    'Mário_Ferreira_dos_Santos',
#    'Martin_Heidegger',
#    'Giambattista_Vico',
#    'Plínio_Salgado',
#    'Descartes',
#    'Hugo_Grotius',
#    'Rodrigo_de_Arriaga',
#    'Xavier_Zubiri',
#    'Immanuel_Kant',
#    'Matthew_Hale_(jurist)',
#    'Christian_von_Wolff'],
#   'Miguel_de_Unamuno': ['Joxe_Azurmendi',
#    'José_Ortega_y_Gasset',
#    'Txillardegi',
#    'Martin_Gardner__Plato,_Kant,_G._K._Chesterton,_William_James,_Char__1',
#    'José_Ferrater_Mora'],
#   'Alexandre_Kojève': ['Allan_Bloom',
#    'Raymond_Queneau',
#    'Jacques_Derrida',
#    'Jacques_Lacan',
#    'Boris_Groys',
#    'Giorgio_Agamben',
#    'Maurice_Merleau-Ponty',
#    'Leo_Strauss',
#    'Louis_Althusser',
#    'André_Breton',
#    'Raymond_Aron',
#    'Michel_Foucault',
#    'Stanley_Rosen',
#    'Juan_José_Sebreli',
#    'Jean-Paul_Sartre',
#    'Georges_Bataille',
#    'Francis_Fukuyama'],
#   'Newton_da_Costa': ['Kazem_Sadegh-Zadeh'],
#   'Jaegwon_Kim': ['Ernest_Sosa', 'Dean_Zimmerman'],
#   'Thomas_of_Erfurt': ['Martin_Heidegger'],
#   'John_Earman': ['Tim_Maudlin'],
#   'Kuno_Fischer': ['Gottlob_Frege',
#    'Wilhelm_Windelband',
#    'John_Pentland_Mahaffy'],
#   'Graham_Harman': ['Steven_Shaviro', 'Timothy_Morton', 'Levi_Bryant'],
#   'Claude_Adrien_Helvétius': ['Jeremy_Bentham',
#    'Juan_Bautista_Alberdi',
#    'William_Godwin',
#    'Cesare,_Marquis_of_Beccaria'],
#   'Norman_Geisler': ['Ravi_Zacharias', 'Frank_Turek'],
#   'Isaac_Abarbanel': ['Leo_Strauss'],
#   'Philip_Pettit': ['José_Luis_Rodríguez_Zapatero'],
#   'Richard_Posner': ['Francesco_Parisi_(economist)'],
#   'Rush_Rhees': ['Dewi_Zephaniah_Phillips'],
#   'Jin_Yuelin': ['Yin_Haiguang', 'Hao_Wang_(academic)'],
#   'Richard_B._Brandt': ['Peter_Railton'],
#   'Imre_Lakatos': ['Alasdair_MacIntyre',
#    'Jerome_Ravetz',
#    'Donald_A._Gillies',
#    'Alan_Chalmers',
#    'David_Corfield',
#    'Paul_Feyerabend',
#    'John_Worrall_(philosopher)'],
#   'Immanuel_Hermann_Fichte': ['Poul_Martin_Møller',
#    'Hermann_Ulrici',
#    'John_Daniel_Morell',
#    'Christian_Hermann_Weisse'],
#   'Robert_Brandom': ['Stanley_Hauerwas',
#    'John_McDowell',
#    'Lynne_Tirrell',
#    'Reza_Negarestani',
#    'Mark_Lance',
#    'Jeffrey_Stout'],
#   'Keiji_Nishitani': ['Masao_Abe'],
#   'Hossein_Nasr': ['William_Chittick'],
#   'Guy_Debord': ['Paul_Virilio',
#    'Davor_Džalto',
#    'Bob_Black',
#    'Douglas_Kellner',
#    'McKenzie_Wark',
#    'Jean_Baudrillard',
#    'John_Zerzan',
#    'Guillaume_Faye'],
#   'Hildegard_of_Bingen__Hildegard_of_Bingen__1': ['Margot_Fassler',
#    'Eugene_III',
#    'Abbot_Suger',
#    'Constructed_language',
#    'Mélanie_Lipinska',
#    'Rudolf_Steiner',
#    'Frederick_I_Barbarossa',
#    'Volmar',
#    'New_Age_movement',
#    'Elisabeth_of_Schönau',
#    'Anastasius_IV',
#    'Grace_McLean'],
#   'Zeno_of_Sidon': ['Philodemus'],
#   'J._L._Austin': ['John_Searle',
#    'Judith_Butler',
#    'P._F._Strawson',
#    'Rom_Harré',
#    'Jürgen_Habermas',
#    'R._M._Hare',
#    'Ian_Hacking',
#    'H._L._A._Hart',
# ...
#   'Emer_de_Vattel': ['Benjamin_Franklin',
#    'Western_philosophy',
#    'Alexander_Hamilton',
#    'George_Washington'],
#   'Tanabe_Hajime': ['Takeshi_Umehara'],
#   'Jan_Baudouin_de_Courtenay': ['Prague_school', 'Nikolai_Trubetzkoy'],
#   'Sir_William_Hamilton,_9th_Baronet': ['James_Hutchison_Stirling',
#    'John_Stuart_Mill',
#    'John_Veitch_(poet)',
#    'Herbert_Spencer'],
#   'Niccolò_Machiavelli': ['Hegel',
#    'Carl_Schmitt',
#    'Claude_Lefort',
#    'Michael_Walzer',
#    'Kenneth_Waltz',
#    'Thomas_Schelling',
#    'Vilfredo_Pareto',
#    'Allan_Bloom',
#    'Jean-Jacques_Rousseau',
#    'Friedrich_Nietzsche',
#    'Leo_Strauss',
#    'Francis_Bacon',
#    'Thomas_Hobbes',
#    'Vincenzo_Cuoco',
#    'David_Hume',
#    'Max_Weber',
#    'James_Harrington_(author)',
#    'Giambattista_Vico',
#    'Mary_G._Dietz',
#    'Giulio_Andreotti',
#    'Denis_Diderot',
#    'Antonio_Gramsci',
#    'Marquis_de_Sade',
#    'Philip_Pettit',
#    'Jean_Charles_Léonard_de_Sismondi',
#    'Louis_Althusser',
#    'John_Adams',
#    'Edward_Gibbon',
#    'Baruch_Spinoza',
#    'Antonio_Negri',
#    'Political_realism'],
#   'Cebes': ['Robert_Moray'],
#   'Max_Black': ['Keith_Donnellan', 'Theodore_Drange'],
#   'Jean_Hyppolite': ['Jacques_Derrida',
#    'Étienne_Balibar',
#    'Sarah_Kofman',
#    'Michel_Foucault',
#    'Gilles_Deleuze',
#    'Michel_Henry',
#    'Gérard_Granel',
#    'Kurt_Mueller-Vollmer'],
#   'Ernst_Laas': ['Paul_Natorp', 'Benno_Kerry'],
#   'Tran_Duc_Thao': ['Juan_José_Sebreli'],
#   'Michel_Foucault': ['William_E._Connolly',
#    'Judith_Butler',
#    'Jasbir_Puar',
#    'Hamid_Dabashi',
#    'Charles_E._Scott',
#    'Douglas_Kellner',
#    'Thomas_Lemke',
#    'Nathan_Widder',
#    'Ian_Parker_(psychologist)',
#    'Nancy_Fraser',
#    'Roberto_Refinetti',
#    'Alexander_Nehamas',
#    'Michel_Onfray',
#    'Michael_J._Shapiro',
#    'Peter_Sloterdijk',
#    'R._Radhakrishnan',
#    'Giorgio_Agamben',
#    'Peter_Hallward',
#    'Philipp_Rosemann',
#    'Jan_Blommaert',
#    'Stephen_A._Webb',
#    'Renata_Salecl',
#    'Peg_Birmingham',
#    'Amina_Mama',
#    'Malek_Shojaee',
#    'Richard_Rorty',
#    'Paul_Rabinow',
#    'Catherine_Malabou',
#    'Fred_Evans_(philosopher)',
#    'Michael_Adrian_Peters',
#    'Gilles_Deleuze',
#    'Achille_Mbembe',
#    'Jacques_Rancière',
#    'Robert_J._C._Young',
#    'Todd_May',
#    'Iris_Marion_Young',
#    'Marcel_Paquet',
#    'Rosi_Braidotti',
#    'Serge_Tisseron',
#    'Amy_Allen_(philosopher)',
#    'Sacha_Golob',
#    'Franson_Manjali',
#    'Ian_Hacking',
#    'Manuel_DeLanda',
#    'Jack_Amariglio',
#    'Judith_Revel',
#    'Bryan_Reynolds_(scholar)',
#    'Paul_R._Patton',
#    'Adriana_Cavarero',
#    'Rey_Chow',
#    'Robert_Bernasconi',
#    'Wendy_Brown_(political_theorist)',
#    'Eugene_Thacker',
#    'Mark_Bevir',
#    'Edward_Said',
#    'Bernard_Bernier',
#    'Franco_Basaglia',
#    'Élisabeth_Roudinesco',
#    'Stanley_Cohen_(sociologist)',
#    'James_Tully_(philosopher)',
#    'Sheldon_Wolin',
#    'Hubert_Dreyfus',
#    'Axel_Honneth',
#    'Arnold_Davidson'],
#   'John_Dupré': ['Ann-Sophie_Barwich'],
#   'Linus_Pauling': ['Arthur_Pardee'],
#   'Amartya_Sen': ['Martha_Nussbaum',
#    'Kaushik_Basu',
#    'Séverine_Deneulin',
#    'Ben_Fine',
#    'Esther_Duflo',
#    'Max_Roser',
#    'Ha-Joon_Chang',
#    'Attilio_Celant',
#    'Mahbub_ul_Haq',
#    'Kotaro_Suzumura',
#    'Sabina_Alkire',
#    'Lars_Pålsson_Syll',
#    'Ingrid_Robeyns',
#    'Jean-Louis_Arcand',
#    'Derek_Parfit',
#    'Tim_Besley',
#    'Jean_Drèze',
#    'Philip_Pettit',
#    'Marc_Fleurbaey',
#    'Inge_Kaul',
#    'Nancy_Folbre',
#    'Andy_Sumner',
#    'Ravi_Kanbur',
#    'Robin_Hahnel',
#    'Tony_Atkinson',
#    'Prasanta_Pattanaik'],
#   'Franz_Bopp': ['Max_Müller', 'Michel_Bréal', 'August_Schleicher'],
#   'Alphonso_Lingis': ['Elizabeth_Grosz'],
#   'Burton_Dreben': ['Warren_Goldfarb', 'Willard_Van_Orman_Quine'],
#   'Richard_Hönigswald': ['Wolfgang_Cramer', 'Norbert_Elias'],
#   'Ludwig_Wittgenstein': ['Alvin_Plantinga',
#    'Pascal_Engel',
#    'Peter_Hacker',
#    'Robert_Brandom',
#    'Rupert_Read__Rupert_Read__1',
#    'Peter_G._Ossorio',
#    'Ronald_A._Kuipers',
#    'Norman_Malcolm',
#    'Tibor_Machan',
#    'Richard_Rorty',
#    'Norwood_Russell_Hanson',
#    'Rudolf_Carnap',
#    'Georg_Henrik_von_Wright',
#    'J._N._Findlay',
#    'John_Hick',
#    'Joseph_Margolis',
#    'Gilles-Gaston_Granger',
#    'Pierre_Hadot',
#    'Saul_Kripke',
#    'William_H._Poteat',
#    'P._F._Strawson',
#    'Gillian_Rose',
#    'Jean-François_Lyotard',
#    'Charles_Stevenson',
#    'Ray_Monk',
#    'Clifford_Geertz',
#    'John_McDowell',
#    'Thomas_Kuhn',
#    'Michele_Marsonet',
#    'Friedrich_Hayek',
#    'Paul_Feyerabend',
#    'G._E._M._Anscombe',
#    'Rose_Rand',
#    'Jesús_Padilla_Gálvez',
#    'David_Bloor',
#    'Barry_Stroud',
#    'Arthur_Danto',
#    'Michael_Tye_(philosopher)',
#    'Casimir_Lewy',
#    'Kojin_Karatani',
#    'Chantal_Mouffe',
#    'James_F._Conant',
#    'Max_Black',
#    'Sandra_Laugier',
#    'Hans_Sluga',
#    'Richard_J._Bernstein',
#    'Gilbert_Ryle',
#    'Bartosz_Brożek',
#    'Donald_Davidson_(philosopher)',
#    'Alan_Turing',
#    'Stephen_Toulmin',
#    'Frank_P._Ramsey',
#    'Heinz_von_Foerster',
#    'Max_Bennett_(scientist)',
#    'John_Searle',
#    'Jules_Vuillemin',
#    'Anthony_Kenny',
#    'Hilary_Putnam',
#    'Michael_Dummett',
#    'Jürgen_Habermas',
#    'Michael_Williams_(philosopher)',
#    'Michael_Adrian_Peters',
#    'Philippa_Foot',
#    'Alice_Crary',
#    'Dewi_Zephaniah_Phillips',
#    'Bertrand_Russell',
#    'Masahiro_Morioka',
#    'Frank_Ramsey_(mathematician)',
#    'Mark_Bevir',
#    'Vienna_Circle',
#    'James_Tully_(philosopher)',
#    'A._J._Ayer',
#    'Daniel_Dennett',
#    'Harry_Frankfurt',
#    'Christopher_Gauker',
#    'Moritz_Schlick',
#    'Helmut_Wautischer',
#    'G._E._Moore',
#    'Jon_Fosse',
#    'Fred_Newman_(philosopher)',
#    'Quentin_Skinner',
#    'Bryan_Magee',
#    'Burton_Dreben',
#    'Giovanni_Piana',
#    'Stanley_Cavell',
#    'Kendall_Walton',
#    'Cora_Diamond',
#    'C._J._F._Williams',
#    'Isaiah_Berlin',
#    'Predrag_Finci',
#    'Ian_Hacking',
#    'R._M._Hare',
#    'H._L._A._Hart',
#    "Peg_O'Connor",
#    'Kevin_Mulligan',
#    'Alasdair_MacIntyre',
#    'Simon_Glendinning',
#    'Roderick_T._Long',
#    'Crispin_Wright',
#    'Bob_Black',
#    'Herbert_McCabe'],
#   'Abraham_ibn_Ezra': ['Baruch_Spinoza'],
#   'J._L._Mackie': ['Colin_MacLeod_(philosopher)',
#    'Michael_Lou_Martin',
#    'Richard_Joyce_(philosopher)',
#    'Michael_Martin_(philosopher)'],
#   'Jean_Piaget': ['Edith_Ackermann',
#    'Lucien_Goldmann',
#    'Andreas_Demetriou',
#    'Kurt_W._Fischer',
#    'Thomas_Kuhn',
#    'Eleanor_Duckworth',
#    'Roberto_Refinetti',
#    'David_Ausubel',
#    'Mario_Christian_Meyer',
#    'David_A._Kolb',
#    'Jürgen_Habermas',
#    'John_Flavell',
#    'Peter_Cathcart_Wason',
#    'Lawrence_Kohlberg',
#    'Angela_Little_(academic)',
#    'Robert_Kegan',
#    'Bärbel_Inhelder',
#    'Kenneth_Kaye',
#    'William_Damon',
#    'Yann_LeCun',
#    'Shlomo_Wolbe',
#    'Seymour_Papert',
#    'Mário_Ferreira_dos_Santos',
#    'Lev_Vygotsky',
#    'Howard_Gardner',
#    'Jerome_Bruner',
#    'Jordan_Peterson'],
#   'Pythagoras': ['Empedocles',
#    'Clement_of_Alexandria',
#    'Mário_Ferreira_dos_Santos',
#    'Xenophanes',
#    'Pythagoreanism',
#    'Philolaus',
#    'Iamblichus',
#    'Plato',
#    'Damo_(philosopher)',
#    'Alcmaeon_of_Croton'],
#   'Alison_Jaggar': ['Sally_Haslanger'],
#   'Jean-Jacques_Rousseau': ['T._M._Scanlon',
#    'John_Rawls',
#    'Ion_Dragoumis',
#    'Johann_Gottlieb_Fichte',
#    'Sarah_Kofman',
#    'Charles_Darwin',
#    'Immanuel_Kant',
#    'Johann_Heinrich_Pestalozzi',
#    'Aminata_Diaw',
#    'Maine_de_Biran',
#    'Adam_Smith',
#    'Nikolay_Chernyshevsky',
#    'Hiroki_Azuma',
#    'Alexander_Herzen',
#    'Dimitri_Kitsikis',
#    'American_Revolution',
#    'Allan_Bloom',
#    'Ljubodrag_Simonović',
#    'Arthur_Schopenhauer',
#    'William_Godwin',
#    'Mario_Christian_Meyer',
#    'Friedrich_Nietzsche',
#    'Simone_Weil',
#    'G.W.F._Hegel',
#    'Leo_Strauss',
#    'Cornelius_Castoriadis',
#    'Karl_Marx',
#    'François-Noël_Babeuf',
#    'Simon_Critchley',
#    'Tan_Malaka',
#    'Johann_Wolfgang_von_Goethe',
#    'David_Hume',
#    'Maximilien_Robespierre',
#    'William_Davies_(political_writer)',
#    'Jacques_Derrida',
#    'Rigas_Feraios',
#    'Louis_Antoine_de_Saint-Just',
#    'Émile_Durkheim',
#    'Claude_Lévi-Strauss',
#    'Liu_Junning',
#    'Philip_Green_(author)',
#    'Sally_Scholz',
#    'Georg_Wilhelm_Friedrich_Hegel',
#    'Denis_Diderot',
#    'Pierre-Joseph_Proudhon',
#    'Thomas_Paine',
#    'Marquis_de_Sade',
#    'John_Dewey',
#    'Henry_David_Thoreau',
#    'Jean-Paul_Sartre',
#    'Henri_Lefebvre',
#    'Mary_Wollstonecraft',
#    'Sigmund_Freud',
#    'Romanticism',
#    'Pierre_Clastres',
#    'Leo_Tolstoy',
#    'René_de_Girardin',
#    'French_Revolution',
#    'Maria_Montessori',
#    'Eileen_Hunt_Botting',
#    'Counter-Enlightenment',
#    'Friedrich_Engels',
#    'B._F._Skinner',
#    'Miguel_de_Unamuno',
#    'Peter_Hallward',
#    'Madame_de_Stael'],
#   'Theophrastus': ['Bion_of_Borysthenes',
#    'Arcesilaus',
#    'Alexander_of_Aphrodisias',
#    'Strato_of_Lampsacus',
#    'Peripatetic_school'],
#   'Anthony_Ashley-Cooper,_3rd_Earl_of_Shaftesbury': ['Thomas_Jefferson',
#    'Francis_Hutcheson_(philosopher)'],
#   'William_Stanley_Jevons': ['Frank_Fetter',
#    'Lionel_Robbins',
#    'Karl_Popper',
#    'Philip_Wicksteed',
#    'Alfred_Marshall',
#    'Irving_Fisher',
#    'Henry_Hazlitt'],
#   'Allan_Bloom': ['William_Galston',
#    'Janet_Ajzenstat',
#    'Alan_Keyes',
#    'Thomas_Pangle',
#    'Harvey_C._Mansfield',
#    'Paul_Wolfowitz',
#    'Francis_Fukuyama'],
#   'Ali_ibn_Sahl_Rabban_al-Tabari': ['Muhammad_ibn_Zakariya_al-Razi'],
#   'Teresa_of_Ávila__Teresa_of_Ávila__1': ['René_Descartes',
#    'Francis_de_Sales',
#    'John_of_the_Cross',
#    'Fénelon',
#    'Thérèse_of_Lisieux'],
#   'Dan_Goldstick': ['Miguel_Figueroa'],
#   'Kenneth_Waltz': ['Randall_Schweller',
#    'Joseph_Nye',
#    'Robert_Gilpin',
#    'Robert_Keohane',
#    'Stephen_Walt',
#    'Fareed_Zakaria',
#    'Robert_Jervis',
#    'John_Mearsheimer'],
#   'Northrop_Frye': ['Stanley_Cavell'],
#   'Alois_Riehl': ['Heinrich_Rickert', 'Moritz_Schlick'],
#   'Martha_Nussbaum': ['Sabina_Alkire',
#    'Louise_Antony',
#    'Ingrid_Robeyns',
#    'Elizabeth_S._Anderson',
#    'Linda_Martín_Alcoff',
#    'David_G._Hebert',
#    'Amartya_Sen'],
#   'Samuel_Clarke': ['William_Wollaston'],
#   'Hendrik_G._Stoker': ['Cornelius_Van_Til'],
#   'Georges_Palante': ['Renzo_Novatore',
#    'Louis_Guilloux',
#    'Jean_Grenier',
#    'Albert_Camus',
#    'Michel_Onfray'],
#   'Pierre_Teilhard_de_Chardin': ['Theodosius_Dobzhansky',
#    'Brian_Swimme',
#    'Anne_Dambricourt-Malassé',
#    'Henri_de_Lubac',
#    'Frank_Tipler',
#    'Pope_Francis',
#    'Thomas_Berry',
#    'Pope_Benedict_XVI'],
#   'Héctor_Herrera_Cajas__Eugenio_Pereira_Mario_Góngora_Juan_Gómez_Millas__1': ['José_Marín_Riveros'],
#   'Jeanne_Hersch': ['Sissela_Bok'],
#   'Leucippus': ['Democritus'],
#   'Ahamed_Muhyudheen_Noorishah_Jeelani': ['Sufism', 'Islamic_philosophy'],
#   'F._C._S._Schiller': ['William_James', 'Victoria,_Lady_Welby'],
#   'Gary_Hatfield': ['R._Lanier_Anderson_(philosopher)'],
#   'Antoun_Saadeh': ['Said_Akl', 'Hafez_al-Assad'],
#   'James_Clerk_Maxwell': ['Albert_Einstein',
#    'Josiah_Willard_Gibbs',
#    'Physics',
#    'William_Davidson_Niven'],
#   'Friedrich_Adolf_Trendelenburg': ['Friedrich_Paulsen',
#    'Wilhelm_Dilthey',
#    'George_Sylvester_Morris',
#    'Rudolf_Christoph_Eucken',
#    'Gottlob_Frege',
#    'Franz_Brentano',
#    'Ernst_Laas',
#    'Søren_Kierkegaard',
#    'Hermann_Cohen'],
#   'Nicolaus_Copernicus': ['Giordano_Bruno',
#    'Johannes_Kepler',
#    'Otto_von_Guericke'],
#   'Max_Planck': ['Hans_Rohrbach',
#    'Lise_Meitner',
#    'Moritz_Schlick',
#    'Karl_Eugen_Guthe'],
#   'Alfred_Russel_Wallace': ['Loren_Eiseley',
#    'James_L._Patton',
#    'Edward_Bagnall_Poulton'],
#   'Sarvepalli_Radhakrishnan': ['Prem_Saran_Satsangi', 'David_Harvey'],
#   'Jean_de_La_Bruyère': ['Juan_Bautista_Alberdi'],
#   'George_Boolos': ['Crispin_Wright'],
#   'Ernst_Friedrich_Apelt': ['Leonard_Nelson'],
#   'B._F._Skinner': ['Maxie_Clarence_Maultsby_Jr.',
#    'Sang-Min_Whang',
#    'Willard_Van_Orman_Quine',
#    'John_Anthony_Nevin',
#    'Robert_Lanza',
#    'Roberto_Refinetti',
#    'A._Charles_Catania'],
#   'Karl_Barth': ['Alasdair_MacIntyre',
#    'Erich_Przywara',
#    'Jacques_Ellul',
#    'Leo_Strauss',
#    'Jean-Luc_Marion'],
#   'Nancy_Fraser': ['Amy_Allen_(philosopher)'],
#   'Antisthenes': ['Diogenes',
#    'Crates_of_Thebes',
#    'Cynicism_(philosophy)',
#    'Stoicism',
#    'Diogenes_of_Sinope'],
#   'Hermann_von_Helmholtz': ['Ivan_Sechenov',
#    'Ludwig_Wittgenstein',
#    'Edmund_Montgomery',
#    'Friedrich_Albert_Lange',
#    'Heinrich_Kayser',
#    'Charles_S._Hastings'],
#   'John_Stuart_Mill': ['Bernard_Gert',
#    'Michael_Sandel',
#    'Edward_J._Hall',
#    'Herman_Daly',
#    'Karl_Kautsky',
#    'José_Ortega_y_Gasset',
#    'Martha_Nussbaum',
#    'Shirzad_Peik_Herfeh',
#    "Domingo_Faustino_Sarmiento__Generation_of_'37,_The_Federalist,_Babeuf,_Bello,__1",
#    'Herbert_Spencer',
#    'John_Gray_(philosopher)',
#    'Friedrich_Hayek',
#    'James_M._Buchanan',
#    'Nikolay_Chernyshevsky',
#    'Paul_Feyerabend',
#    'Paul_Dirac',
#    'Bernard_Bosanquet_(philosopher)',
#    'Friedrich_Nietzsche',
#    'Robert_Sugden_(economist)',
#    'Alfred_Binet',
#    'Geoffrey_Scarre',
#    'Milton_Friedman',
#    'Isaiah_Berlin',
#    'Robert_Paul_Wolff',
#    'Émile_Durkheim',
#    'Henry_Sidgwick',
#    'Philip_Green_(author)',
#    'Max_Hirsch_(economist)',
#    'Joel_Feinberg',
#    'Derek_Parfit',
#    'Mortimer_J._Adler',
#    'Keith_Lewin',
#    'Louis_Blanc',
#    'Karl_Popper',
#    'David_Lyons_(philosopher)',
#    'José_Guilherme_Merquior',
#    'Christoph_von_Sigwart',
#    'William_James',
#    'Eileen_Hunt_Botting',
#    'Alexander_Bain',
#    'George_Reisman',
#    'Will_Kymlicka'],
#   'W._D._Ross': ['Robert_Audi',
#    'Bernard_Gert',
#    'Thomas_Hurka',
#    'Tara_Smith_(philosopher)',
#    'Jonathan_Dancy'],
#   'Hans_Lipps': ['Knud_Ejler_Løgstrup'],
#   'August_Schleicher': ['Johannes_Schmidt_(linguist)', 'August_Leskien'],
#   'Albertus_Magnus': ['Paul_of_Venice',
#    'Thomas_Aquinas__Thomas_Aquinas__1',
#    'Nicholas_of_Cusa'],
#   'Hans_Reichenbach': ['Adolf_Grünbaum',
#    'Hilmi_Ziya_Ülken',
#    'Takiyettin_Mengüşoğlu',
#    'Michael_Friedman_(philosopher)',
#    'İoanna_Kuçuradi',
#    'Bas_van_Fraassen',
#    'Carl_Gustav_Hempel',
#    'Hilary_Putnam'],
#   'Carl_Gustav_Carus': ['Karl_Robert_Eduard_von_Hartmann'],
#   'Novalis': ['Walter_Benjamin'],
#   'William_L._Rowe': ['Paul_Draper_(philosopher)',
#    'Michael_Bergmann_(philosopher)'],
#   'Thales': ['Anaximander', 'Xenophanes', 'Heraclitus'],
#   'Al-Ghazali': ['René_Descartes',
#    'Maimonides',
#    'Thomas_Aquinas__Thomas_Aquinas__1',
#    'Averroes',
#    'Bar_Hebraeus',
#    'Tan_Malaka',
#    'Sadegh_Zibakalam',
#    'Ramon_Llull__Ramon_Llull__1',
#    'Necip_Fazıl_Kısakürek',
#    'Qadi_Thanaullah_Panipati'],
#   'Jonathan_Glover': ['Derek_Parfit', 'John_Gardner_(legal_philosopher)'],
#   'Evandro_Agazzi': ['Carlo_Penco'],
#   'Al-Sijzi': ['Al-Biruni'],
#   'Theodor_W._Adorno': ['Giles_Hooper',
#    'Judith_Butler',
#    'Raymond_Geuss',
#    'Werner_Krieglstein',
#    'Herbert_Marcuse',
#    'Sheldon_Wolin',
#    'Slavoj_Žižek',
#    'Axel_Honneth',
#    'Predrag_Finci',
#    'Max_Horkheimer',
#    'John_Zerzan',
#    'Jürgen_Habermas',
#    'Alain_Badiou',
#    'Fredric_Jameson'],
#   'Yaşar_Nuri_Öztürk': ['Alevism'],
#   'David_Wiggins': ['Jonathan_Dancy', 'John_McDowell'],
#   'Johann_Kaspar_Bluntschli': ['Richard_T._Ely', 'Frank_J._Goodnow'],
#   'Paul_Yorck_von_Wartenburg': ['Martin_Heidegger'],
#   'Renzo_Novatore': ['Severino_Di_Giovanni',
#    'Bruno_Filippi',
#    'Antonio_Gramsci'],
#   'Francisco_Varela': ['Bradford_Keeney',
#    'Evan_Thompson',
#    'Cornelius_Castoriadis',
#    'Carlos_Gershenson',
#    'Bracha_L._Ettinger',
#    'Joe_L._Kincheloe'],
#   'Hannah_Arendt': ['Alain_Finkielkraut',
#    'Seyla_Benhabib',
#    'Claude_Lefort',
#    'Noëlle_McAfee',
#    'Giorgio_Agamben',
#    'Ronald_A._Kuipers',
#    'Cornelius_Castoriadis',
#    'Raymond_Aron',
#    'Jacques_Rancière',
#    'Mario_Kopić',
#    'Heinrich_Blücher',
#    'Murray_Bookchin',
#    'Mary_G._Dietz',
#    'Amy_Allen_(philosopher)',
#    'Lauren_Swayne_Barthold',
#    'Adriana_Cavarero',
#    'William_H._Poteat',
#    'Richard_J._Bernstein',
#    'Julia_Kristeva',
#    'Sheldon_Wolin',
#    'Jarrett_Zigon',
#    'Brigitte_Secard',
#    'Richard_Sennett'],
#   'Gemistus_Pletho': ['Hermonymus_of_Sparta',
#    'Nicholas_of_Cusa',
#    'John_Argyropoulos',
#    'Bessarion',
#    'Marsilio_Ficino',
#    "Cosimo_de'_Medici"],
#   ...}}

# %%
dataset.to_pickle('../data/dbpedia.pkl')

# %%
dataset = pd.read_pickle('../data/dbpedia.pkl')

# %%
wikipedia = MediaWiki()

# %%
wikipedia.page('Ludwig_Wittgenstein').content
# Out:
# 'Ludwig Josef Johann Wittgenstein ( VIT-gən-s(h)tyne; German: [ˈluːtvɪç ˈvɪtɡn̩ˌʃtaɪn]; 26 April 1889 – 29 April 1951) was an Austrian-British philosopher who worked primarily in logic, the philosophy of mathematics, the philosophy of mind, and the philosophy of language.\nFrom 1929 to 1947, Wittgenstein taught at the University of Cambridge. During his lifetime he published just one slim book (the 75-page Tractatus Logico-Philosophicus, 1921), one article ("Some Remarks on Logical Form", 1929), one book review and a children\'s dictionary. His voluminous manuscripts were edited and published posthumously. The first and best-known of this posthumous series is the 1953 book Philosophical Investigations. His teacher, Bertrand Russell, described Wittgenstein as perhaps the most perfect example I have ever known of genius as traditionally conceived; passionate, profound, intense, and dominating.Born in Vienna into one of Europe\'s richest families, he inherited a fortune from his father in 1913. He initially made some donations to artists and writers, and then, in a period of severe personal depression after the First World War, he gave away his entire fortune to his brothers and sisters. Three of his four brothers committed suicide, which Wittgenstein had also contemplated. He left academia several times—serving as an officer on the front line during World War I, where he was decorated a number of times for his courage; teaching in schools in remote Austrian villages where he encountered controversy for hitting children when they made mistakes in mathematics; and working as a hospital porter during World War II in London, where he told patients not to take the drugs they were prescribed while largely managing to keep secret the fact that he was one of the world\'s most famous philosophers.His philosophy is often divided into an early period, exemplified by the Tractatus, and a later period, articulated primarily in the Philosophical Investigations. The "Early Wittgenstein" was concerned with the logical relationship between propositions and the world and he believed that by providing an account of the logic underlying this relationship, he had solved all philosophical problems. The "Later Wittgenstein", however, rejected many of the assumptions of the Tractatus, arguing that the meaning of words is best understood as their use within a given language-game.\nA survey among American university and college teachers ranked the Investigations as the most important book of 20th-century philosophy, standing out as the one crossover masterpiece in twentieth-century philosophy, appealing across diverse specializations and philosophical orientations. The Investigations also ranked 54th on a list of most influential twentieth-century works in cognitive science prepared by the University of Minnesota\'s Center for Cognitive Sciences. However, in the words of his friend Georg Henrik von Wright, he believed that his ideas were generally misunderstood and distorted even by those who professed to be his disciples. He doubted he would be better understood in the future. He once said he felt as though he was writing for people who would think in a different way, breathe a different air of life, from that of present-day men.\n\n\n== Background ==\n\n\n=== The Wittgensteins ===\n\nAccording to a family tree prepared in Jerusalem after World War II, Wittgenstein\'s paternal great-great-grandfather was Moses Meier, a Jewish land agent who lived with his wife, Brendel Simon, in Bad Laasphe in the Principality of Wittgenstein, Westphalia. In July 1808, Napoleon issued a decree that everyone, including Jews, must adopt an inheritable family surname, so Meier\'s son, also Moses, took the name of his employers, the Sayn-Wittgensteins, and became Moses Meier Wittgenstein. His son, Hermann Christian Wittgenstein – who took the middle name "Christian" to distance himself from his Jewish background – married Fanny Figdor, also Jewish, who converted to Protesta ...

# %%
# %%time
dataset['text'] = dataset['philosopher_url'].apply(get_wiki_article)
# Out:
# CPU times: user 1min 40s, sys: 4.04 s, total: 1min 44s
# Wall time: 2h 9min 38s

# %%
dataset
# Out:
#                    philosopher_url  \
# 0                      Stephen_Law
# 1              Henry_S._Richardson
# 2               John_Amos_Comenius
# 3                      Javier_Gomá
# 4                       Oskar_Negt
# ...                            ...
# 6084           Stanisław_Krajewski
# 6085  Patrick_Stokes_(philosopher)
# 6086                    Ernst_Mach
# 6087                Jessica_Pierce
# 6088            Hans-Georg_Gadamer
#
#                                             name  \
# 0                                  [Stephen Law]
# 1                          [Henry S. Richardson]
# 2     [John Amos Comenius, Johann Amos Comenius]
# 3                           [Javier Gomá Lanzón]
# 4                                            NaN
# ...                                          ...
# 6084                                         NaN
# 6085                            [Patrick Stokes]
# 6086                                [Ernst Mach]
# 6087                            [Jessica Pierce]
# 6088                        [Hans-Georg Gadamer]
#
#                                                abstract  \
# 0     Stephen Law  (born 1960) is an English philoso...
# 1     Henry S. Richardson is an American philosopher...
# 2     John Amos Comenius (Czech: Jan Amos Komenský; ...
# 3     Javier Gomá Lanzón (Bilbao, 24 May 1965) is a ...
# 4     Oskar Negt (German pronunciation: [ˈneːkt]; bo...
# ...                                                 ...
# 6084  Stanisław Krajewski (born 1950) is a Polish ph...
# 6085  Patrick Stokes (born 1978) is an Australian ph...
# 6086  Ernst Waldfried Josef Wenzel Mach (; German: [...
# 6087  Jessica Pierce (born October 21, 1965) is an A...
# 6088  Hans-Georg Gadamer (; German: [ˈɡaːdamɐ]; Febr...
#
#                                           notable_ideas  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6084                                                NaN
# 6085                                                NaN
# 6086                                                NaN
# 6087                                                NaN
# 6088  [Consciousness, Fusion_of_horizons, Practical_...
#
#                                       influence_inbound  \
# 0                                                   NaN
# 1                                          [John_Rawls]
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6084                                                NaN
# 6085                                                NaN
# 6086  [Gustav_Fechner, George_Berkeley, Andreas_von_...
# 6087                                                NaN
# 6088  [Wilhelm_Dilthey, Friedrich_Schleiermacher, Ka...
#
#                                      influence_outbound  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6084                                                NaN
# 6085                                                NaN
# 6086  [Pierre_Duhem, Henri_Poincaré, Ludwig_Boltzman...
# 6087                                                NaN
# 6088  [Babette_Babich, John_McDowell, Reinhart_Kosel...
#
#                                    undirected_influence  \
# 0                                                   NaN
# 1                                          [John_Rawls]
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6084                                                NaN
# 6085                                                NaN
# 6086  [William_James, Friedrich_Hayek, Albert_Einste...
# 6087                                                NaN
# 6088  [Augustine, Paul_Natorp, Martin_Heidegger, Nic...
#
#                                                    text
# 0     Stephen Law  (born 1960) is an English philoso...
# 1     Henry S. Richardson is an American philosopher...
# 2     John Amos Comenius (Czech: Jan Amos Komenský; ...
# 3     Javier Gomá Lanzón (Bilbao, 24 May 1965) is a ...
# 4     Oskar Negt (German pronunciation: [ˈneːkt]; bo...
# ...                                                 ...
# 6084  Stanisław Krajewski (born 1950) is a Polish ph...
# 6085  Patrick Stokes (born 1978) is an Australian ph...
# 6086  Ernst Waldfried Josef Wenzel Mach (; German: [...
# 6087  Jessica Pierce (born October 21, 1965) is an A...
# 6088  Hans-Georg Gadamer (; German: [ˈɡaːdamɐ]; Febr...
#
# [6089 rows x 8 columns]

# %%
dataset.to_pickle('../data/dbpedia_with_articles.pkl')

# %%
dataset[dataset['text'] == -1]
# Out:
#                                 philosopher_url               name  \
# 7            Petar_II_Petrovi%C4%87-Njego%C5%A1                NaN
# 27            Samuel_Butler_(1835%E2%80%931902)                NaN
# 78    Jayar%C4%81%C5%9Bi_Bha%E1%B9%AD%E1%B9%ADa                NaN
# 110                  Ra%C3%BAl_Scalabrini_Ortiz                NaN
# 121                            Jakob_B%C3%B6hme                NaN
# ...                                         ...                ...
# 5644                            Alan_H._Goldman  [Alan H. Goldman]
# 5709             %C5%9A%C4%81ntarak%E1%B9%A3ita                NaN
# 5746                               David_Sherry                NaN
# 5789           Adolfo_S%C3%A1nchez_V%C3%A1zquez                NaN
# 5926                       Kuki_Sh%C5%ABz%C5%8D                NaN
#
#                                                abstract notable_ideas  \
# 7                                                   NaN           NaN
# 27                                                  NaN           NaN
# 78                                                  NaN           NaN
# 110                                                 NaN           NaN
# 121                                                 NaN           NaN
# ...                                                 ...           ...
# 5644  Alan Harris Goldman (born 1945) is an American...           NaN
# 5709                                                NaN           NaN
# 5746                                                NaN           NaN
# 5789                                                NaN           NaN
# 5926                                                NaN           NaN
#
#      influence_inbound influence_outbound undirected_influence text
# 7                  NaN                NaN                  NaN   -1
# 27                 NaN                NaN                  NaN   -1
# 78                 NaN                NaN                  NaN   -1
# 110                NaN                NaN                  NaN   -1
# 121                NaN                NaN                  NaN   -1
# ...                ...                ...                  ...  ...
# 5644               NaN                NaN                  NaN   -1
# 5709               NaN                NaN                  NaN   -1
# 5746               NaN                NaN                  NaN   -1
# 5789               NaN                NaN                  NaN   -1
# 5926               NaN                NaN                  NaN   -1
#
# [126 rows x 8 columns]
